# %%
# Enter your script here.

import numpy as np
import pandas as pd
import csv
import re
import calendar
import datetime
format_str = '%Y-%m-%d' # The format
import functools 
import operator
import simplejson as json

def check_columns(data):
    for columns in data:
      print(columns + ":  " +  str(len(pd.unique(data[columns]))) )
      print(pd.unique(data[columns]))
      print('++++++++++++++++++')

def splitQuery(column):
    listOfthings = "'" + column.astype(str).str.cat(sep="', '") + "'"
    return listOfthings

# %%
dados_brutos = pd.read_csv('dados_brutos.csv')
dados_cidades = pd.read_csv('municipios.csv')
dados_estados = pd.read_csv('estados.csv')

dados_brutos

dados_geo = dados_cidades.merge(dados_estados,left_on='codigo_uf', right_on='codigo_uf',suffixes=('_cidade', '_estado'))

# %%
dados_geo[dados_geo['nome_cidade']=='São Paulo']
# Out:
#       codigo_ibge nome_cidade  latitude  longitude  capital  codigo_uf  uf  \
# 4694      3550308   São Paulo  -23.5329   -46.6395        1         35  SP
#
#      nome_estado
# 4694   São Paulo

# %%
dados_geo['cidade_estado'] = dados_geo['nome_cidade'] + ' - ' + dados_geo['uf']

# %%
dados_brutos.columns = dados_brutos.columns.str.replace(' ', '_')

regex = r"\_\(\w*|\W*\)"
regex_under = r"(^\_)"

dict_para_novos_nomes = {}

for items in dados_brutos.columns:
    ##caixa baixa
    item_caixa_baixa = items.lower()
    ##tirar parenteses bizarros e underscore comeco
    novo_item = re.sub(regex,'',item_caixa_baixa)
    sem_under = re.sub(regex_under,'',novo_item)
    ##tirar co2 com superscript
    dict_para_novos_nomes[items] = sem_under.replace('co²','co2')

#renomear colunas aqui
dados_brutos.rename(columns = dict_para_novos_nomes,inplace=True)

# %%
pd.unique(dados_brutos['estado'])
# Out:
# array(['Pará', 'Minas Gerais', 'São Paulo ', 'Distrito Federal',
#        'São Paulo', 'Paraná', 'Santa Catarina', 'Ceará', 'Goiás',
#        'Amazonas', 'Rio de Janeiro', 'Rio Grande do Sul', 'Pernambuco',
#        'Bahia', 'Espírito Santo'], dtype=object)

# %%
dados_brutos.replace(to_replace=r'\%', value='', regex=True, inplace=True)
dados_brutos.replace(to_replace = 'dockless', value = np.NaN, inplace=True)

lista_colunas_trocar = ['estações','mulheres','homens','15_até_29_anos','30_até_59_anos','acima_de_60']

dicionario_final = {}
dicionario_final['local'] = 'Brasil'
dicionario_final['sistema_total'] = []
dicionario_final['sistema_por_estado'] = []

dict_siglas = {
    'AC': 'Acre',
    'AL': 'Alagoas',
    'AP': 'Amapá',
    'AM': 'Amazonas',
    'BA': 'Bahia',
    'CE': 'Ceará',
    'DF': 'Distrito Federal',
    'ES': 'Espírito Santo',
    'GO': 'Goiás',
    'MA': 'Maranhão',
    'MT': 'Mato Grosso',
    'MS': 'Mato Grosso do Sul',
    'MG': 'Minas Gerais',
    'PA': 'Pará',
    'PB': 'Paraíba',
    'PR': 'Paraná',
    'PE': 'Pernambuco',
    'PI': 'Piauí',
    'RJ': 'Rio de Janeiro',
    'RN': 'Rio Grande do Norte',
    'RS': 'Rio Grande do Sul',
    'RO': 'Rondônia',
    'RR': 'Roraima',
    'SC': 'Santa Catarina',
    'SP': 'São Paulo',
    'SE': 'Sergipe',
    'TO': 'Tocantins'
}

def get_key(val,siglas): 
    for key, value in siglas.items(): 
         if val == value: 
             return key 
        
    return "key doesn't exist"

### dados agregados de sistemas

dados_brutos['estado'] = dados_brutos['estado'].str.rstrip()

for estados in pd.unique(dados_brutos['estado']):
    print(estados)
    dict_estado = {}
    dict_estado['estado'] = estados
    frame_estado = dados_brutos[dados_brutos['estado'] == estados]
    dict_estado['sistemas'] = []
    for sis_por_estado in pd.unique(frame_estado['sistema']):
        sigla = get_key(estados.rstrip(),dict_siglas)
        dicionario_final['sistema_total'].append(sis_por_estado + ' – ' + sigla)
        dict_estado['sistemas'].append(sis_por_estado + ' – ' + sigla)
    dicionario_final['sistema_por_estado'].append(dict_estado)

dicionario_final['operadora'] = pd.unique(dados_brutos['operadora']).tolist()

### dados agregados de estações, bicicletas, patinetes, viagens, distância
for col_errada in lista_colunas_trocar:
    dados_brutos[col_errada] = pd.to_numeric(dados_brutos[col_errada], errors='coerce')

lista_para_somar = ['estações','bicicletas_elétricas','bicicletas','patinetes_elétricos','viagens_diárias','média_distância_percorrida_por_dia','usuários','emissões_de_co2_evitadas']        

for col_para_somar in lista_para_somar:
    if np.isnan(dados_brutos[col_para_somar].sum(min_count=1)) == True:
        dicionario_final[col_para_somar] = 'Dados não disponíveis'
    else:
        dicionario_final[col_para_somar] = dados_brutos[col_para_somar].sum(min_count=1)

## dados agregados de dados demográficos
lista_demograficos = ['mulheres','homens','15_até_29_anos','30_até_59_anos','acima_de_60']

for col_porcentagem in lista_demograficos:
    lista_valores_totais = []
    print(col_porcentagem)
    for municipio in pd.unique(dados_brutos['cidade']):
        frame_municipio = dados_brutos[dados_brutos['cidade'] ==  municipio]
        if np.isnan(frame_municipio['usuários'].sum(min_count=1)) == True:
            dicionario_final[col_porcentagem] = 'Dados não disponíveis'
        else:
            for sistema in pd.unique(frame_municipio['sistema']):
                frame_sistema = frame_municipio[frame_municipio['sistema'] == sistema]
                if np.isnan(frame_sistema['usuários'].sum(min_count=1)) == True:
                    dicionario_final[col_porcentagem] = 'Dados não disponíveis'
                else:
                    for veiculo in pd.unique(frame_sistema['tipologia_do_veículo']):
                        frame_final = frame_sistema[frame_sistema['tipologia_do_veículo'] == veiculo]
#                         if np.isnan(frame_final['usuários']) == True:
                        if frame_final['usuários'].empty == True:
                            dicionario_final[col_porcentagem] = 'Dados não disponíveis'
                        else:
                            valor_absoluto = (frame_final['usuários'].values*frame_final[col_porcentagem].values)/100
                            print('======== valor abs ========')
                            print(valor_absoluto[0])
                            print(valor_absoluto)
                            lista_valores_totais.append(valor_absoluto[0])                        
    if not lista_valores_totais:
        dicionario_final[col_porcentagem] = 'Dados não disponíveis'
    else:
        print(lista_valores_totais)
        dicionario_final[col_porcentagem] = functools.reduce((lambda x, y: x * y), lista_valores_totais)
# Out:
# Pará
# Minas Gerais
# São Paulo
# Distrito Federal
# Paraná
# Santa Catarina
# Ceará
# Goiás
# Amazonas
# Rio de Janeiro
# Rio Grande do Sul
# Pernambuco
# Bahia
# Espírito Santo
# mulheres
# ======== valor abs ========
# 478.0293
# [478.0293]
# ======== valor abs ========
# 14827.326
# [14827.326]
# ======== valor abs ========
# 2986.3439999999996
# [2986.344]
# ======== valor abs ========
# 28356.3504
# [28356.3504]
# ======== valor abs ========
# 2800.8762
# [2800.8762]
# ======== valor abs ========
# 28.0002
# [28.0002]
# ======== valor abs ========
# 11426.5566
# [11426.5566]
# ======== valor abs ========
# 1556.1984
# [1556.1984]
# ======== valor abs ========
# 2034.1791999999998
# [2034.1792]
# ======== valor abs ========
# 7979.963199999999
# [7979.9632]
# [478.0293, 14827.326, 2986.3439999999996, 28356.3504, 2800.8762, 28.0002, 11426.5566, 1556.1984, 2034.1791999999998, 7979.963199999999]
# homens
# ======== valor abs ========
# 570.9707
# [570.9707]
# ======== valor abs ========
# 21837.674
# [21837.674]
# ======== valor abs ========
# 5449.656
# [5449.656]
# ======== valor abs ========
# 28721.6496
# [28721.6496]
# ======== valor abs ========
# 3397.1238
# [3397.1238]
# ======== valor abs ========
# 40.99980000000001
# [40.9998]
# ======== valor abs ========
# 11326.4434
# [11326.4434]
# ======== valor abs ========
# 1086.8015999999998
# [1086.8016]
# ======== valor abs ========
# 2113.8208
# [2113.8208]
# ======== valor abs ========
# 7772.036800000001
# [7772.0368]
# [570.9707, 21837.674, 5449.656, 28721.6496, 3397.1238, 40.99980000000001, 11326.4434, 1086.8015999999998, 2113.8208, 7772.036800000001]
# 15_até_29_anos
# ======== valor abs ========
# 454.95129999999995
# [454.9513]
# ======== valor abs ========
# 19025.468500000003
# [19025.4685]
# ======== valor abs ========
# 2833.6524000000004
# [2833.6524]
# ======== valor abs ========
# 36952.2972
# [36952.2972]
# ======== valor abs ========
# 2843.0226000000002
# [2843.0226]
# ======== valor abs ========
# 24.9987
# [24.9987]
# ======== valor abs ========
# 10532.363699999998
# [10532.3637]
# ======== valor abs ========
# 1142.8332
# [1142.8332]
# ======== valor abs ========
# 1660.0296000000003
# [1660.0296]
# ======== valor abs ========
# 6940.3312
# [6940.3312]
# [454.95129999999995, 19025.468500000003, 2833.6524000000004, 36952.2972, 2843.0226000000002, 24.9987, 10532.363699999998, 1142.8332, 1660.0296000000003, 6940.3312]
# 30_até_59_anos
# ======== valor abs ========
# 572.9638
# [572.9638]
# ======== valor abs ========
# 17122.555
# [17122.555]
# ======== valor abs ========
# 5298.6516
# [5298.6516]
# ======== valor abs ========
# 19309.487399999998
# [19309.4874]
# ======== valor abs ========
# 3258.2886
# [3258.2886]
# ======== valor abs ========
# 44.0013
# [44.0013]
# ======== valor abs ========
# 11538.046300000002
# [11538.0463]
# ======== valor abs ========
# 1434.0918
# [1434.0918]
# ======== valor abs ========
# 2419.1136
# [2419.1136]
# ======== valor abs ========
# 8468.2752
# [8468.2752]
# [572.9638, 17122.555, 5298.6516, 19309.487399999998, 3258.2886, 44.0013, 11538.046300000002, 1434.0918, 2419.1136, 8468.2752]
# acima_de_60
# ======== valor abs ========
# 20.98
# [20.98]
# ======== valor abs ========
# 516.9765
# [516.9765]
# ======== valor abs ========
# 302.8524
# [302.8524]
# ======== valor abs ========
# 816.2153999999999
# [816.2154]
# ======== valor abs ========
# 97.30860000000001
# [97.3086]
# ======== valor abs ========
# 0.0
# [0.]
# ======== valor abs ========
# 682.59
# [682.59]
# ======== valor abs ========
# 66.075
# [66.075]
# ======== valor abs ========
# 68.85679999999999
# [68.8568]
# ======== valor abs ========
# 343.3936
# [343.3936]
# [20.98, 516.9765, 302.8524, 816.2153999999999, 97.30860000000001, 0.0, 682.59, 66.075, 68.85679999999999, 343.3936]

# %%
def cidadePorc(frame,dici):
    if frame[col_por].isna().values.any():
        dici[col_por] = 'Dados não disponíveis'
    else:
        filter_frame = frame[~pd.isnull(frame['usuários'])]
        null_frame = frame[pd.isnull(frame['usuários'])]
        
        if len(filter_frame.index) == 1:
            dici[col_por] = filter_frame[col_por].values[0]
        elif len(filter_frame.index) > 1:
            total_usuario = filter_frame['usuários'].sum()
            total_porc = filter_frame[col_por].sum()
            valor_absoluto = (total_porc/total_usuario)*100
            dici[col_por] = valor_absoluto
        else:
            if len(null_frame) == 1:
                dici[col_por] = null_frame[col_por].values[0]
            else:
                frame_sistema = frame[frame['sistema'] == sistema]

                if frame_sistema[col_por].isna().values.any():
                    dici[col_por] = 'Dados não disponíveis'
                else:
                    filter_frame = frame_sistema[~pd.isnull(frame['usuários'])]
                    null_frame = frame_sistema[pd.isnull(frame_sistema['usuários'])]

                    if len(filter_frame.index) == 1:
                        dici[col_por] = filter_frame[col_por].values[0]
                    elif len(filter_frame.index) > 1:
                        total_usuario = filter_frame['usuários'].sum()
                        total_porc = filter_frame[col_por].sum()
                        valor_absoluto = (total_porc/total_usuario)*100
                        dici[col_por] = valor_absoluto
                    else:
                        if len(null_frame.index) == 1:
                            check_columns(null_frame)
                            dici[col_por] = null_frame[col_por].values[0]
                        else:
                            total_usuario = null_frame['usuários'].sum()
                            total_porc = null_frame[col_por].sum()
                            valor_absoluto = (total_porc/total_usuario)*100
                            dici[col_por] = valor_absoluto
            
    return dici[col_por]

def getPorcentagens(frame,dici):
    
    if frame[col_por].isna().values.any():
        dici[col_por] = 'Dados não disponíveis'
    else:
        filter_frame = frame[~pd.isnull(frame['usuários'])]
        null_frame = frame[pd.isnull(frame['usuários'])]
        if len(filter_frame.index) == 1:
            dici[col_por] = filter_frame[col_por].values[0]
        elif len(filter_frame.index) > 1:
            total_usuario = filter_frame['usuários'].sum()
            total_porc = filter_frame[col_por].sum()
            valor_absoluto = (total_porc/total_usuario)*100
            dici[col_por] = valor_absoluto
        else:
            if len(null_frame.index) == 1:
                check_columns(null_frame)
                dici[col_por] = null_frame[col_por].values[0]
            else:
                total_usuario = null_frame['usuários'].sum()
                total_porc = null_frame[col_por].sum()
                valor_absoluto = (total_porc/total_usuario)*100
                dici[col_por] = valor_absoluto
            
    return dici[col_por]

# %%
dados_brutos
# Out:
#                  cidade             estado        região  \
# 0                 Belém               Pará         Norte
# 1        Belo Horizonte       Minas Gerais       Sudeste
# 2        Belo Horizonte       Minas Gerais       Sudeste
# 3        Belo Horizonte       Minas Gerais       Sudeste
# 4              Bertioga          São Paulo       Sudeste
# 5              Brasília   Distrito Federal  Centro-Oeste
# 6              Brasília   Distrito Federal  Centro-Oeste
# 7              Campinas          São Paulo       Sudeste
# 8              Campinas          São Paulo       Sudeste
# 9              Curitiba             Paraná           Sul
# 10             Curitiba             Paraná           Sul
# 11        Florianópolis     Santa Catarina           Sul
# 12        Florianópolis     Santa Catarina           Sul
# 13            Fortaleza              Ceará      Nordeste
# 14            Fortaleza              Ceará      Nordeste
# 15              Goiânia              Goiás  Centro-Oeste
# 16             Ilhabela          São Paulo       Sudeste
# 17         Juiz de Fora       Minas Gerais       Sudeste
# 18               Manaus           Amazonas         Norte
# 19               Maricá     Rio de Janeiro       Sudeste
# 20              Pelotas  Rio Grande do Sul           Sul
# 21            Petrolina         Pernambuco      Nordeste
# 22         Porto Alegre  Rio Grande do Sul           Sul
# 23         Porto Alegre  Rio Grande do Sul           Sul
# 24         Porto Alegre  Rio Grande do Sul           Sul
# 25               Recife         Pernambuco      Nordeste
# 26       Rio de Janeiro     Rio de Janeiro       Sudeste
# 27       Rio de Janeiro     Rio de Janeiro       Sudeste
# 28       Rio de Janeiro     Rio de Janeiro       Sudeste
# 29       Rio de Janeiro     Rio de Janeiro       Sudeste
# 30             Salvador              Bahia      Nordeste
# 31             Salvador              Bahia      Nordeste
# 32               Santos          São Paulo       Sudeste
# 33               Santos          São Paulo       Sudeste
# 34  São José dos Campos          São Paulo       Sudeste
# 35  São José dos Campos          São Paulo       Sudeste
# 36  São José dos Campos          São Paulo       Sudeste
# 37  São José dos Campos          São Paulo       Sudeste
# 38            São Paulo          São Paulo       Sudeste
# 39            São Paulo          São Paulo       Sudeste
# 40            São Paulo          São Paulo       Sudeste
# 41            São Paulo          São Paulo       Sudeste
# 42            São Paulo          São Paulo       Sudeste
# 43            São Paulo          São Paulo       Sudeste
# 44                Serra     Espírito Santo       Sudeste
# 45             Sorocaba          São Paulo       Sudeste
# 46           Vila Velha     Espírito Santo       Sudeste
# 47           Vila Velha     Espírito Santo       Sudeste
# 48              Vitória     Espírito Santo       Sudeste
# 49              Vitória     Espírito Santo       Sudeste
#
#                  sistema               operadora tipologia_do_veículo  \
# 0             Bike Belém                 Tembici            Bicicleta
# 1                Bike BH                 Serttel            Bicicleta
# 2                 Yellow                  Yellow            Bicicleta
# 3                 Yellow                  Yellow    Patinete Eletrico
# 4               Rivibike                 Tembici            Bicicleta
# 5              Mais Bike                 Serttel            Bicicleta
# 6                 Yellow                  Yellow    Patinete Eletrico
# 7                 Yellow                  Yellow            Bicicleta
# 8                 Yellow                  Yellow    Patinete Eletrico
# 9                 Yellow                  Yellow            Bicicleta
# 10                Yellow                  Yellow    Patinete Eletrico
# 11                Yellow                  Yellow            Bicicleta
# 12                Yellow                  Yellow    Patinete Eletrico
# 13   Bicicleta Integrada                 Serttel            Bicicleta
# 14            Bicicletar                 Serttel            Bicicleta
# 15             GynDebike                 Serttel            Bicicleta
# 16                Yellow                  Yellow            Bicicleta
# 17        Unimed Bike JF                 Tembici            Bicicleta
# 18              Manôbike                 Tembici            Bicicleta
# 19                Maricá                 Serttel            Bicicleta
# 20              Bike Pel                 Serttel            Bicicleta
# 21             Petrobike                 Serttel            Bicicleta
# 22              Bike PoA                 Tembici            Bicicleta
# 23                Yellow                  Yellow            Bicicleta
# 24                Yellow                  Yellow    Patinete Eletrico
# 25               Bike PE                 Tembici            Bicicleta
# 26                  Grin                    Grin    Patinete Eletrico
# 27                  Lime                    Lime    Patinete Eletrico
# 28              Bike Rio                 Tembici            Bicicleta
# 29                Yellow                  Yellow    Patinete Eletrico
# 30  Salvador Vai de Bike  Prefeitura de Salvador            Bicicleta
# 31         Bike Salvador                 Tembici            Bicicleta
# 32           Bike Santos                 Serttel            Bicicleta
# 33      Bike Kids Santos                 Tembici            Bicicleta
# 34            Bike Sanja                 Serttel            Bicicleta
# 35          Mobilicidade            Mobilicidade            Bicicleta
# 36                Yellow                  Yellow            Bicicleta
# 37                Yellow                  Yellow    Patinete Eletrico
# 38                  Grin                    Grin    Patinete Eletrico
# 39                  Lime                    Lime    Patinete Eletrico
# 40                Yellow                  Yellow            Bicicleta
# 41                Yellow                  Yellow    Patinete Eletrico
# 42            CicloSampa          Agencia Trunfo            Bicicleta
# 43            Bike Sampa                 Tembici            Bicicleta
# 44            Bike Serra                 Serttel            Bicicleta
# 45           Integrabike                 Tembici            Bicicleta
# 46               Bike VV                 Tembici            Bicicleta
# 47                Yellow                  Yellow    Patinete Eletrico
# 48          Bike Vitória                 Serttel            Bicicleta
# 49                Yellow                  Yellow    Patinete Eletrico
#
#     estações  bicicletas_elétricas  bicicletas  patinetes_elétricos  \
# 0        NaN                   NaN         NaN                  NaN
# 1       14.0                   NaN       140.0                  NaN
# 2        NaN                   NaN         NaN                  NaN
# 3        NaN                   NaN         NaN                  NaN
# 4        NaN                   NaN         NaN                  NaN
# 5       50.0                   NaN       500.0                  NaN
# 6        NaN                   NaN         NaN                  NaN
# 7        NaN                   NaN         NaN                  NaN
# 8        NaN                   NaN         NaN                  NaN
# 9        NaN                   NaN         NaN                  NaN
# 10       NaN                   NaN         NaN                  NaN
# 11       NaN                   NaN         NaN                  NaN
# 12       NaN                   NaN         NaN                  NaN
# 13       7.0                   NaN       350.0                  NaN
# 14      85.0                   NaN       850.0                  NaN
# 15      20.0                   NaN       200.0                  NaN
# 16       NaN                   NaN         NaN                  NaN
# 17       NaN                   NaN         NaN                  NaN
# 18       NaN                   NaN         NaN                  NaN
# 19      20.0                   NaN       200.0                  NaN
# 20       NaN                   NaN       100.0                  NaN
# 21       7.0                   NaN        70.0                  NaN
# 22      41.0                   NaN       410.0                  NaN
# 23       NaN                   NaN         NaN                  NaN
# 24       NaN                   NaN         NaN                  NaN
# 25      80.0                   NaN       800.0                  NaN
# 26       NaN                   NaN         NaN                  NaN
# 27       NaN                   NaN         NaN                  NaN
# 28     260.0                   NaN      2600.0                  NaN
# 29       NaN                   NaN         NaN                  NaN
# 30       NaN                   NaN         NaN                  NaN
# 31      50.0                   NaN       400.0                  NaN
# 32      37.0                   NaN       370.0                  NaN
# 33       NaN                   NaN         NaN                  NaN
# 34       NaN                   NaN       100.0                  NaN
# 35       NaN                   NaN         NaN                  NaN
# 36       NaN                   NaN         NaN                  NaN
# 37       NaN                   NaN         NaN                  NaN
# 38       NaN                   NaN         NaN                  NaN
# 39       NaN                   NaN         NaN                  NaN
# 40       NaN                   NaN         NaN                  NaN
# 41       NaN                   NaN         NaN                  NaN
# 42       NaN                   NaN         NaN                  NaN
# 43     260.0                   NaN      2700.0                  NaN
# 44      20.0                   NaN       200.0                  NaN
# 45       NaN                   NaN         NaN                  NaN
# 46      20.0                   NaN       200.0                  NaN
# 47       NaN                   NaN         NaN                  NaN
# 48      33.0                   NaN       330.0                  NaN
# 49       NaN                   NaN         NaN                  NaN
#
#     viagens_diárias  média_distância_percorrida_por_dia  usuários  mulheres  \
# 0               NaN                                 NaN       NaN       NaN
# 1             158.0                                 NaN    1049.0     45.57
# 2               NaN                                 NaN       NaN       NaN
# 3               NaN                                 NaN       NaN       NaN
# 4               NaN                                 NaN       NaN       NaN
# 5             830.0                                 NaN   36665.0     40.44
# 6               NaN                                 NaN       NaN       NaN
# 7               NaN                                 NaN       NaN       NaN
# 8               NaN                                 NaN       NaN       NaN
# 9               NaN                                 NaN       NaN       NaN
# 10              NaN                                 NaN       NaN       NaN
# 11              NaN                                 NaN       NaN       NaN
# 12              NaN                                 NaN       NaN       NaN
# 13            128.0                                 NaN    8436.0     35.40
# 14           1317.0                                 NaN   57078.0     49.68
# 15            206.0                                 NaN    6198.0     45.19
# 16              NaN                                 NaN       NaN       NaN
# 17              NaN                                 NaN       NaN       NaN
# 18              NaN                                 NaN       NaN       NaN
# 19              NaN                                 NaN       NaN       NaN
# 20              NaN                                 NaN       NaN       NaN
# 21              1.0                                 NaN      69.0     40.58
# 22           2294.0                            12777.94       NaN     29.62
# 23              NaN                                 NaN       NaN       NaN
# 24              NaN                                 NaN       NaN       NaN
# 25           2821.0                            14044.01       NaN     26.38
# 26              NaN                                 NaN       NaN       NaN
# 27              NaN                                 NaN       NaN       NaN
# 28          17503.0                            97807.67       NaN     22.59
# 29              NaN                                 NaN       NaN       NaN
# 30              NaN                                 NaN       NaN       NaN
# 31           1284.0                             8263.34       NaN     28.55
# 32           1521.0                                 NaN   22753.0     50.22
# 33              NaN                                 NaN       NaN       NaN
# 34             31.0                              383.00    2643.0     58.88
# 35              NaN                                 NaN       NaN       NaN
# 36              NaN                                 NaN       NaN       NaN
# 37              NaN                                 NaN       NaN       NaN
# 38              NaN                                 NaN       NaN       NaN
# 39              NaN                                 NaN       NaN       NaN
# 40              NaN                                 NaN       NaN       NaN
# 41              NaN                                 NaN       NaN       NaN
# 42              NaN                                 NaN       NaN       NaN
# 43           5800.0                            29437.00       NaN     19.31
# 44            177.0                                 NaN    4148.0     49.04
# 45              NaN                                 NaN       NaN       NaN
# 46           2059.0                            10686.35       NaN     30.91
# 47              NaN                                 NaN       NaN       NaN
# 48            655.0                                 NaN   15752.0     50.66
# 49              NaN                                 NaN       NaN       NaN
#
#     homens  15_até_29_anos  30_até_59_anos  acima_de_60  \
# 0      NaN             NaN             NaN          NaN
# 1    54.43           43.37           54.62         2.00
# 2      NaN             NaN             NaN          NaN
# 3      NaN             NaN             NaN          NaN
# 4      NaN             NaN             NaN          NaN
# 5    59.56           51.89           46.70         1.41
# 6      NaN             NaN             NaN          NaN
# 7      NaN             NaN             NaN          NaN
# 8      NaN             NaN             NaN          NaN
# 9      NaN             NaN             NaN          NaN
# 10     NaN             NaN             NaN          NaN
# 11     NaN             NaN             NaN          NaN
# 12     NaN             NaN             NaN          NaN
# 13   64.60           33.59           62.81         3.59
# 14   50.32           64.74           33.83         1.43
# 15   54.81           45.87           52.57         1.57
# 16     NaN             NaN             NaN          NaN
# 17     NaN             NaN             NaN          NaN
# 18     NaN             NaN             NaN          NaN
# 19     NaN             NaN             NaN          NaN
# 20     NaN             NaN             NaN          NaN
# 21   59.42           36.23           63.77         0.00
# 22   62.80           47.04           43.96         1.48
# 23     NaN             NaN             NaN          NaN
# 24     NaN             NaN             NaN          NaN
# 25   65.87           58.66           36.31         1.38
# 26     NaN             NaN             NaN          NaN
# 27     NaN             NaN             NaN          NaN
# 28   70.31           38.05           52.90         3.02
# 29     NaN             NaN             NaN          NaN
# 30     NaN             NaN             NaN          NaN
# 31   65.83           40.61           51.13         3.95
# 32   49.78           46.29           50.71         3.00
# 33     NaN             NaN             NaN          NaN
# 34   41.12           43.24           54.26         2.50
# 35     NaN             NaN             NaN          NaN
# 36     NaN             NaN             NaN          NaN
# 37     NaN             NaN             NaN          NaN
# 38     NaN             NaN             NaN          NaN
# 39     NaN             NaN             NaN          NaN
# 40     NaN             NaN             NaN          NaN
# 41     NaN             NaN             NaN          NaN
# 42     NaN             NaN             NaN          NaN
# 43   70.91           45.71           48.03         0.73
# 44   50.96           40.02           58.32         1.66
# 45     NaN             NaN             NaN          NaN
# 46   59.60           37.46           47.25         3.24
# 47     NaN             NaN             NaN          NaN
# 48   49.34           44.06           53.76         2.18
# 49     NaN             NaN             NaN          NaN
#
#     emissões_de_co2_evitadas  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                       NaN
# 18                       NaN
# 19                       NaN
# 20                       NaN
# 21                       NaN
# 22                     75.51
# 23                       NaN
# 24                       NaN
# 25                     74.34
# 26                       NaN
# 27                       NaN
# 28                     63.53
# 29                       NaN
# 30                       NaN
# 31                     38.30
# 32                       NaN
# 33                       NaN
# 34                      3.65
# 35                       NaN
# 36                       NaN
# 37                       NaN
# 38                       NaN
# 39                       NaN
# 40                       NaN
# 41                       NaN
# 42                       NaN
# 43                    226.14
# 44                       NaN
# 45                       NaN
# 46                     71.30
# 47                       NaN
# 48                       NaN
# 49                       NaN
#
#                               fonte_e_escopo_temporal
# 0                                                 NaN
# 1   Emissões de CO² evitadas: Calculado com base n...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   Emissões de CO² evitadas: Calculado com base n...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  Emissões de CO² evitadas: Calculado com base n...
# 14  Emissões de CO² evitadas: Calculado com base n...
# 15  Emissões de CO² evitadas: Calculado com base n...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20  Emissões de CO² evitadas: Calculado com base n...
# 21  Emissões de CO² evitadas: Calculado com base n...
# 22  Emissões de CO² evitadas: Calculado com base n...
# 23                                                NaN
# 24                                                NaN
# 25  Emissões de CO² evitadas: Calculado com base n...
# 26                                                NaN
# 27                                                NaN
# 28  Emissões de CO² evitadas: Calculado com base n...
# 29                                                NaN
# 30                                                NaN
# 31  Emissões de CO² evitadas: Calculado com base n...
# 32  Emissões de CO² evitadas: Calculado com base n...
# 33                                                NaN
# 34  Emissões de CO² evitadas: Calculado com base n...
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43  Emissões de CO² evitadas: Calculado com base n...
# 44  Emissões de CO² evitadas: Calculado com base n...
# 45                                                NaN
# 46  Emissões de CO² evitadas: Calculado com base n...
# 47                                                NaN
# 48  Emissões de CO² evitadas: Calculado com base n...
# 49                                                NaN

# %%
# for cidade_item in pd.unique(dados_brutos['cidade']):
#     ## criar corte nos dados só com a cidade selecionada no momento dentro do loop
#     ## vamos fazer calculos em cima disso
#     frame_cidade = dados_brutos[dados_brutos['cidade'] == cidade_item]
#     print(cidade_item)
#     dic_cidade = {}
#     dic_cidade['cidade'] = cidade_item.rstrip()
    
#     id_cidade_estado = cidade_item.rstrip() + ' ' + frame_cidade.iloc[0]['estado'].rstrip()
# #     dic_cidade['estado'] = id_cidade_estado
#     print(id_cidade_estado)
#     frame_com_latlong = dados_geo[dados_geo['cidade_estado'] == id_cidade_estado]
    
#     dic_cidade['lat'] = frame_com_latlong['latitude']
#     dic_cidade['long'] = frame_com_latlong['longitude']
# Out:
# Belém
# Belém Pará
# Belo Horizonte
# Belo Horizonte Minas Gerais
# Bertioga
# Bertioga São Paulo
# Brasília
# Brasília Distrito Federal
# Campinas
# Campinas São Paulo
# Curitiba
# Curitiba Paraná
# Florianópolis
# Florianópolis Santa Catarina
# Fortaleza
# Fortaleza Ceará
# Goiânia
# Goiânia Goiás
# Ilhabela
# Ilhabela São Paulo
# Juiz de Fora
# Juiz de Fora Minas Gerais
# Manaus
# Manaus Amazonas
# Maricá
# Maricá Rio de Janeiro
# Pelotas
# Pelotas Rio Grande do Sul
# Petrolina
# Petrolina Pernambuco
# Porto Alegre
# Porto Alegre Rio Grande do Sul
# Recife
# Recife Pernambuco
# Rio de Janeiro
# Rio de Janeiro Rio de Janeiro
# Salvador
# Salvador Bahia
# Santos
# Santos São Paulo
# São José dos Campos
# São José dos Campos São Paulo
# São Paulo
# São Paulo São Paulo
# Serra
# Serra Espírito Santo
# Sorocaba
# Sorocaba São Paulo
# Vila Velha
# Vila Velha Espírito Santo
# Vitória
# Vitória Espírito Santo

# %%
dicionario_final['municipios'] = []

lista_para_somar_2 = ['estações','bicicletas_elétricas','bicicletas','patinetes_elétricos','viagens_diárias','média_distância_percorrida_por_dia','usuários','emissões_de_co2_evitadas']
lista_demograficos_2 = ['mulheres','homens','15_até_29_anos','30_até_59_anos','acima_de_60']


## ler todas as cidades no arquivo, e para cada cidade, criar um dicionario/objeto
## aos poucos, adicionar propriedades únicas como nome e outras coisas mais

for cidade_item in pd.unique(dados_brutos['cidade']):
    ## criar corte nos dados só com a cidade selecionada no momento dentro do loop
    ## vamos fazer calculos em cima disso
    frame_cidade = dados_brutos[dados_brutos['cidade'] == cidade_item]
    print(cidade_item)
    dic_cidade = {}
    dic_cidade['cidade'] = cidade_item.rstrip().lstrip()
    
    id_cidade_estado = cidade_item.rstrip().lstrip() + ' ' + frame_cidade.iloc[0]['estado'].rstrip().lstrip()
#     dic_cidade['estado'] = id_cidade_estado
    print(id_cidade_estado)
    frame_com_latlong = dados_geo[dados_geo['cidade_estado'] == id_cidade_estado]
    
    dic_cidade['lat'] = frame_com_latlong.iloc[0]['latitude']
    dic_cidade['long'] = frame_com_latlong.iloc[0]['longitude']
    dic_cidade['estado'] = frame_cidade.iloc[0]['estado']
    dic_cidade['sistemas'] = []
    dic_cidade['modais'] = []
    
    ### dados gerais das cidades
    for col_para_somar in lista_para_somar_2:
        if np.isnan(frame_cidade[col_para_somar].sum(min_count=1)) == True:
            dic_cidade[col_para_somar] = 'Dados não disponíveis'
        else:
            dic_cidade[col_para_somar] = frame_cidade[col_para_somar].sum(min_count=1)
            
    ### dados demograficos das cidades
    for col_por in lista_demograficos_2:
        cidadePorc(frame_cidade,dic_cidade)
           
    ##########################################################################################
    ### dados agregados de sistemas
    for sistema in pd.unique(frame_cidade['sistema']):
        frame_sistema = frame_cidade[frame_cidade['sistema'] == sistema]
        dict_sistema = {}
        dict_sistema['sistema'] = sistema
        dict_sistema['cidade'] = dic_cidade['cidade']
#         dict_sistema['estado'] = dic_cidade['estado']        
        dict_sistema['lat'] = dic_cidade['lat']
        dict_sistema['long'] = dic_cidade['long']

        ### dados gerais dos sistemas
        for col_para_somar in lista_para_somar_2:
            if np.isnan(frame_sistema[col_para_somar].sum(min_count=1)) == True:
                dict_sistema[col_para_somar] = 'Dados não disponíveis'
            else:
                dict_sistema[col_para_somar] = frame_sistema[col_para_somar].sum(min_count=1)
        
        ### dados demograficos dos sistemas
        for col_por in lista_demograficos_2:
            getPorcentagens(frame_sistema,dict_sistema)
     
        ##########################################################################################
        ### Adicionar dicionario/objeto de cada veiculo dentro de cada sistema; passo final!
        dict_sistema['veiculos'] = []
        for veiculo in pd.unique(frame_sistema['tipologia_do_veículo']):
            print(veiculo)
            dict_veiculo = {}
            dict_veiculo['lat'] = dic_cidade['lat']
            dict_veiculo['long'] = dic_cidade['long']
            frame_veiculo = frame_sistema[frame_sistema['tipologia_do_veículo'] == veiculo]
            lista_colunas_veiculo = frame_veiculo.columns.values
            for colunas_linha in lista_colunas_veiculo:
                dict_veiculo[colunas_linha] = frame_veiculo.iloc[0][colunas_linha]
            dict_sistema['veiculos'].append(dict_veiculo)
        ##########################################################################################
        
        ### Adicionar sistemas e modais a sua cidade
        dic_cidade['sistemas'].append(dict_sistema)
    
    ##########################################################################################
    ### dados agregados de MODAIS
    for modal in pd.unique(frame_cidade['tipologia_do_veículo']):
        frame_modal = frame_cidade[frame_cidade['tipologia_do_veículo'] == modal]
        dict_modal = {}
        dict_modal['tipologia_do_veículo'] = modal
        dict_modal['cidade'] = dic_cidade['cidade']
#         dict_modal['estado'] = dic_cidade['estado']
        dict_modal['lat'] = dic_cidade['lat']
        dict_modal['long'] = dic_cidade['long']

        ### dados gerais dos modais
        for col_para_somar in lista_para_somar_2:
            if np.isnan(frame_modal[col_para_somar].sum(min_count=1)) == True:
                dict_modal[col_para_somar] = 'Dados não disponíveis'
            else:
                dict_modal[col_para_somar] = frame_modal[col_para_somar].sum(min_count=1)
        
        ### dados demograficos dos sistemas
        for col_por in lista_demograficos_2:
            getPorcentagens(frame_modal,dict_modal)
        
        dic_cidade['modais'].append(dict_modal)
        
    ##########################################################################################
    ### Adicionar cidades ao objeto final
    dic_cidade
    dicionario_final['municipios'].append(dic_cidade)
# Out:
# Belém
# Belém Pará
# Bicicleta
# Belo Horizonte
# Belo Horizonte Minas Gerais
# Bicicleta
# Bicicleta
# Patinete Eletrico
# Bertioga
# Bertioga São Paulo
# Bicicleta
# Brasília
# Brasília Distrito Federal
# Bicicleta
# Patinete Eletrico
# Campinas
# Campinas São Paulo
# Bicicleta
# Patinete Eletrico
# Curitiba
# Curitiba Paraná
# Bicicleta
# Patinete Eletrico
# Florianópolis
# Florianópolis Santa Catarina
# Bicicleta
# Patinete Eletrico
# Fortaleza
# Fortaleza Ceará
# Bicicleta
# Bicicleta
# Goiânia
# Goiânia Goiás
# Bicicleta
# Ilhabela
# Ilhabela São Paulo
# Bicicleta
# Juiz de Fora
# Juiz de Fora Minas Gerais
# Bicicleta
# Manaus
# Manaus Amazonas
# Bicicleta
# Maricá
# Maricá Rio de Janeiro
# Bicicleta
# Pelotas
# Pelotas Rio Grande do Sul
# Bicicleta
# Petrolina
# Petrolina Pernambuco
# Bicicleta
# Porto Alegre
# Porto Alegre Rio Grande do Sul
# cidade:  1
# ['Porto Alegre']
# ++++++++++++++++++
# estado:  1
# ['Rio Grande do Sul']
# ++++++++++++++++++
# região:  1
# ['Sul']
# ++++++++++++++++++
# sistema:  1
# ['Bike PoA']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [41.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [410.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [2294.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [12777.94]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [29.62]
# ++++++++++++++++++
# homens:  1
# [62.8]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [47.04]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [43.96]
# ++++++++++++++++++
# acima_de_60:  1
# [1.48]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [75.51]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes aos meses de dezembro de 2018 a maio de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.\n']
# ++++++++++++++++++
# cidade:  1
# ['Porto Alegre']
# ++++++++++++++++++
# estado:  1
# ['Rio Grande do Sul']
# ++++++++++++++++++
# região:  1
# ['Sul']
# ++++++++++++++++++
# sistema:  1
# ['Bike PoA']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [41.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [410.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [2294.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [12777.94]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [29.62]
# ++++++++++++++++++
# homens:  1
# [62.8]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [47.04]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [43.96]
# ++++++++++++++++++
# acima_de_60:  1
# [1.48]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [75.51]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes aos meses de dezembro de 2018 a maio de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.\n']
# ++++++++++++++++++
# cidade:  1
# ['Porto Alegre']
# ++++++++++++++++++
# estado:  1
# ['Rio Grande do Sul']
# ++++++++++++++++++
# região:  1
# ['Sul']
# ++++++++++++++++++
# sistema:  1
# ['Bike PoA']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [41.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [410.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [2294.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [12777.94]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [29.62]
# ++++++++++++++++++
# homens:  1
# [62.8]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [47.04]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [43.96]
# ++++++++++++++++++
# acima_de_60:  1
# [1.48]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [75.51]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes aos meses de dezembro de 2018 a maio de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.\n']
# ++++++++++++++++++
# cidade:  1
# ['Porto Alegre']
# ++++++++++++++++++
# estado:  1
# ['Rio Grande do Sul']
# ++++++++++++++++++
# região:  1
# ['Sul']
# ++++++++++++++++++
# sistema:  1
# ['Bike PoA']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [41.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [410.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [2294.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [12777.94]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [29.62]
# ++++++++++++++++++
# homens:  1
# [62.8]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [47.04]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [43.96]
# ++++++++++++++++++
# acima_de_60:  1
# [1.48]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [75.51]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes aos meses de dezembro de 2018 a maio de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.\n']
# ++++++++++++++++++
# cidade:  1
# ['Porto Alegre']
# ++++++++++++++++++
# estado:  1
# ['Rio Grande do Sul']
# ++++++++++++++++++
# região:  1
# ['Sul']
# ++++++++++++++++++
# sistema:  1
# ['Bike PoA']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [41.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [410.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [2294.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [12777.94]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [29.62]
# ++++++++++++++++++
# homens:  1
# [62.8]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [47.04]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [43.96]
# ++++++++++++++++++
# acima_de_60:  1
# [1.48]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [75.51]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes aos meses de dezembro de 2018 a maio de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.\n']
# ++++++++++++++++++
# Bicicleta
# Bicicleta
# Patinete Eletrico
# Recife
# Recife Pernambuco
# cidade:  1
# ['Recife']
# ++++++++++++++++++
# estado:  1
# ['Pernambuco']
# ++++++++++++++++++
# região:  1
# ['Nordeste']
# ++++++++++++++++++
# sistema:  1
# ['Bike PE']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [80.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [800.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [2821.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [14044.01]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [26.38]
# ++++++++++++++++++
# homens:  1
# [65.87]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [58.66]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [36.31]
# ++++++++++++++++++
# acima_de_60:  1
# [1.38]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [74.34]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes aos meses de dezembro de 2018 a maio de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.\n']
# ++++++++++++++++++
# cidade:  1
# ['Recife']
# ++++++++++++++++++
# estado:  1
# ['Pernambuco']
# ++++++++++++++++++
# região:  1
# ['Nordeste']
# ++++++++++++++++++
# sistema:  1
# ['Bike PE']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [80.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [800.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [2821.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [14044.01]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [26.38]
# ++++++++++++++++++
# homens:  1
# [65.87]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [58.66]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [36.31]
# ++++++++++++++++++
# acima_de_60:  1
# [1.38]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [74.34]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes aos meses de dezembro de 2018 a maio de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.\n']
# ++++++++++++++++++
# cidade:  1
# ['Recife']
# ++++++++++++++++++
# estado:  1
# ['Pernambuco']
# ++++++++++++++++++
# região:  1
# ['Nordeste']
# ++++++++++++++++++
# sistema:  1
# ['Bike PE']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [80.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [800.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [2821.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [14044.01]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [26.38]
# ++++++++++++++++++
# homens:  1
# [65.87]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [58.66]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [36.31]
# ++++++++++++++++++
# acima_de_60:  1
# [1.38]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [74.34]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes aos meses de dezembro de 2018 a maio de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.\n']
# ++++++++++++++++++
# cidade:  1
# ['Recife']
# ++++++++++++++++++
# estado:  1
# ['Pernambuco']
# ++++++++++++++++++
# região:  1
# ['Nordeste']
# ++++++++++++++++++
# sistema:  1
# ['Bike PE']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [80.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [800.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [2821.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [14044.01]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [26.38]
# ++++++++++++++++++
# homens:  1
# [65.87]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [58.66]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [36.31]
# ++++++++++++++++++
# acima_de_60:  1
# [1.38]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [74.34]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes aos meses de dezembro de 2018 a maio de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.\n']
# ++++++++++++++++++
# cidade:  1
# ['Recife']
# ++++++++++++++++++
# estado:  1
# ['Pernambuco']
# ++++++++++++++++++
# região:  1
# ['Nordeste']
# ++++++++++++++++++
# sistema:  1
# ['Bike PE']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [80.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [800.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [2821.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [14044.01]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [26.38]
# ++++++++++++++++++
# homens:  1
# [65.87]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [58.66]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [36.31]
# ++++++++++++++++++
# acima_de_60:  1
# [1.38]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [74.34]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes aos meses de dezembro de 2018 a maio de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.\n']
# ++++++++++++++++++
# Bicicleta
# cidade:  1
# ['Recife']
# ++++++++++++++++++
# estado:  1
# ['Pernambuco']
# ++++++++++++++++++
# região:  1
# ['Nordeste']
# ++++++++++++++++++
# sistema:  1
# ['Bike PE']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [80.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [800.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [2821.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [14044.01]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [26.38]
# ++++++++++++++++++
# homens:  1
# [65.87]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [58.66]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [36.31]
# ++++++++++++++++++
# acima_de_60:  1
# [1.38]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [74.34]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes aos meses de dezembro de 2018 a maio de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.\n']
# ++++++++++++++++++
# cidade:  1
# ['Recife']
# ++++++++++++++++++
# estado:  1
# ['Pernambuco']
# ++++++++++++++++++
# região:  1
# ['Nordeste']
# ++++++++++++++++++
# sistema:  1
# ['Bike PE']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [80.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [800.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [2821.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [14044.01]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [26.38]
# ++++++++++++++++++
# homens:  1
# [65.87]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [58.66]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [36.31]
# ++++++++++++++++++
# acima_de_60:  1
# [1.38]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [74.34]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes aos meses de dezembro de 2018 a maio de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.\n']
# ++++++++++++++++++
# cidade:  1
# ['Recife']
# ++++++++++++++++++
# estado:  1
# ['Pernambuco']
# ++++++++++++++++++
# região:  1
# ['Nordeste']
# ++++++++++++++++++
# sistema:  1
# ['Bike PE']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [80.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [800.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [2821.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [14044.01]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [26.38]
# ++++++++++++++++++
# homens:  1
# [65.87]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [58.66]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [36.31]
# ++++++++++++++++++
# acima_de_60:  1
# [1.38]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [74.34]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes aos meses de dezembro de 2018 a maio de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.\n']
# ++++++++++++++++++
# cidade:  1
# ['Recife']
# ++++++++++++++++++
# estado:  1
# ['Pernambuco']
# ++++++++++++++++++
# região:  1
# ['Nordeste']
# ++++++++++++++++++
# sistema:  1
# ['Bike PE']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [80.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [800.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [2821.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [14044.01]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [26.38]
# ++++++++++++++++++
# homens:  1
# [65.87]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [58.66]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [36.31]
# ++++++++++++++++++
# acima_de_60:  1
# [1.38]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [74.34]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes aos meses de dezembro de 2018 a maio de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.\n']
# ++++++++++++++++++
# cidade:  1
# ['Recife']
# ++++++++++++++++++
# estado:  1
# ['Pernambuco']
# ++++++++++++++++++
# região:  1
# ['Nordeste']
# ++++++++++++++++++
# sistema:  1
# ['Bike PE']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [80.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [800.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [2821.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [14044.01]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [26.38]
# ++++++++++++++++++
# homens:  1
# [65.87]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [58.66]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [36.31]
# ++++++++++++++++++
# acima_de_60:  1
# [1.38]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [74.34]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes aos meses de dezembro de 2018 a maio de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.\n']
# ++++++++++++++++++
# Rio de Janeiro
# Rio de Janeiro Rio de Janeiro
# Patinete Eletrico
# Patinete Eletrico
# cidade:  1
# ['Rio de Janeiro']
# ++++++++++++++++++
# estado:  1
# ['Rio de Janeiro']
# ++++++++++++++++++
# região:  1
# ['Sudeste']
# ++++++++++++++++++
# sistema:  1
# ['Bike Rio']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [260.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [2600.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [17503.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [97807.67]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [22.59]
# ++++++++++++++++++
# homens:  1
# [70.31]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [38.05]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [52.9]
# ++++++++++++++++++
# acima_de_60:  1
# [3.02]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [63.53]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes ao mês de março de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.\n']
# ++++++++++++++++++
# cidade:  1
# ['Rio de Janeiro']
# ++++++++++++++++++
# estado:  1
# ['Rio de Janeiro']
# ++++++++++++++++++
# região:  1
# ['Sudeste']
# ++++++++++++++++++
# sistema:  1
# ['Bike Rio']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [260.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [2600.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [17503.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [97807.67]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [22.59]
# ++++++++++++++++++
# homens:  1
# [70.31]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [38.05]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [52.9]
# ++++++++++++++++++
# acima_de_60:  1
# [3.02]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [63.53]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes ao mês de março de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.\n']
# ++++++++++++++++++
# cidade:  1
# ['Rio de Janeiro']
# ++++++++++++++++++
# estado:  1
# ['Rio de Janeiro']
# ++++++++++++++++++
# região:  1
# ['Sudeste']
# ++++++++++++++++++
# sistema:  1
# ['Bike Rio']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [260.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [2600.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [17503.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [97807.67]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [22.59]
# ++++++++++++++++++
# homens:  1
# [70.31]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [38.05]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [52.9]
# ++++++++++++++++++
# acima_de_60:  1
# [3.02]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [63.53]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes ao mês de março de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.\n']
# ++++++++++++++++++
# cidade:  1
# ['Rio de Janeiro']
# ++++++++++++++++++
# estado:  1
# ['Rio de Janeiro']
# ++++++++++++++++++
# região:  1
# ['Sudeste']
# ++++++++++++++++++
# sistema:  1
# ['Bike Rio']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [260.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [2600.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [17503.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [97807.67]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [22.59]
# ++++++++++++++++++
# homens:  1
# [70.31]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [38.05]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [52.9]
# ++++++++++++++++++
# acima_de_60:  1
# [3.02]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [63.53]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes ao mês de março de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.\n']
# ++++++++++++++++++
# cidade:  1
# ['Rio de Janeiro']
# ++++++++++++++++++
# estado:  1
# ['Rio de Janeiro']
# ++++++++++++++++++
# região:  1
# ['Sudeste']
# ++++++++++++++++++
# sistema:  1
# ['Bike Rio']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [260.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [2600.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [17503.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [97807.67]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [22.59]
# ++++++++++++++++++
# homens:  1
# [70.31]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [38.05]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [52.9]
# ++++++++++++++++++
# acima_de_60:  1
# [3.02]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [63.53]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes ao mês de março de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.\n']
# ++++++++++++++++++
# Bicicleta
# Patinete Eletrico
# cidade:  1
# ['Rio de Janeiro']
# ++++++++++++++++++
# estado:  1
# ['Rio de Janeiro']
# ++++++++++++++++++
# região:  1
# ['Sudeste']
# ++++++++++++++++++
# sistema:  1
# ['Bike Rio']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [260.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [2600.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [17503.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [97807.67]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [22.59]
# ++++++++++++++++++
# homens:  1
# [70.31]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [38.05]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [52.9]
# ++++++++++++++++++
# acima_de_60:  1
# [3.02]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [63.53]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes ao mês de março de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.\n']
# ++++++++++++++++++
# cidade:  1
# ['Rio de Janeiro']
# ++++++++++++++++++
# estado:  1
# ['Rio de Janeiro']
# ++++++++++++++++++
# região:  1
# ['Sudeste']
# ++++++++++++++++++
# sistema:  1
# ['Bike Rio']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [260.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [2600.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [17503.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [97807.67]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [22.59]
# ++++++++++++++++++
# homens:  1
# [70.31]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [38.05]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [52.9]
# ++++++++++++++++++
# acima_de_60:  1
# [3.02]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [63.53]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes ao mês de março de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.\n']
# ++++++++++++++++++
# cidade:  1
# ['Rio de Janeiro']
# ++++++++++++++++++
# estado:  1
# ['Rio de Janeiro']
# ++++++++++++++++++
# região:  1
# ['Sudeste']
# ++++++++++++++++++
# sistema:  1
# ['Bike Rio']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [260.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [2600.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [17503.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [97807.67]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [22.59]
# ++++++++++++++++++
# homens:  1
# [70.31]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [38.05]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [52.9]
# ++++++++++++++++++
# acima_de_60:  1
# [3.02]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [63.53]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes ao mês de março de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.\n']
# ++++++++++++++++++
# cidade:  1
# ['Rio de Janeiro']
# ++++++++++++++++++
# estado:  1
# ['Rio de Janeiro']
# ++++++++++++++++++
# região:  1
# ['Sudeste']
# ++++++++++++++++++
# sistema:  1
# ['Bike Rio']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [260.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [2600.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [17503.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [97807.67]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [22.59]
# ++++++++++++++++++
# homens:  1
# [70.31]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [38.05]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [52.9]
# ++++++++++++++++++
# acima_de_60:  1
# [3.02]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [63.53]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes ao mês de março de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.\n']
# ++++++++++++++++++
# cidade:  1
# ['Rio de Janeiro']
# ++++++++++++++++++
# estado:  1
# ['Rio de Janeiro']
# ++++++++++++++++++
# região:  1
# ['Sudeste']
# ++++++++++++++++++
# sistema:  1
# ['Bike Rio']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [260.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [2600.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [17503.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [97807.67]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [22.59]
# ++++++++++++++++++
# homens:  1
# [70.31]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [38.05]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [52.9]
# ++++++++++++++++++
# acima_de_60:  1
# [3.02]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [63.53]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes ao mês de março de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.\n']
# ++++++++++++++++++
# Salvador
# Salvador Bahia
# Bicicleta
# cidade:  1
# ['Salvador']
# ++++++++++++++++++
# estado:  1
# ['Bahia']
# ++++++++++++++++++
# região:  1
# ['Nordeste']
# ++++++++++++++++++
# sistema:  1
# ['Bike Salvador']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [50.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [400.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [1284.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [8263.34]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [28.55]
# ++++++++++++++++++
# homens:  1
# [65.83]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [40.61]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [51.13]
# ++++++++++++++++++
# acima_de_60:  1
# [3.95]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [38.3]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes aos meses de dezembro de 2018 a maio de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.']
# ++++++++++++++++++
# cidade:  1
# ['Salvador']
# ++++++++++++++++++
# estado:  1
# ['Bahia']
# ++++++++++++++++++
# região:  1
# ['Nordeste']
# ++++++++++++++++++
# sistema:  1
# ['Bike Salvador']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [50.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [400.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [1284.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [8263.34]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [28.55]
# ++++++++++++++++++
# homens:  1
# [65.83]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [40.61]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [51.13]
# ++++++++++++++++++
# acima_de_60:  1
# [3.95]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [38.3]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes aos meses de dezembro de 2018 a maio de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.']
# ++++++++++++++++++
# cidade:  1
# ['Salvador']
# ++++++++++++++++++
# estado:  1
# ['Bahia']
# ++++++++++++++++++
# região:  1
# ['Nordeste']
# ++++++++++++++++++
# sistema:  1
# ['Bike Salvador']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [50.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [400.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [1284.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [8263.34]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [28.55]
# ++++++++++++++++++
# homens:  1
# [65.83]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [40.61]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [51.13]
# ++++++++++++++++++
# acima_de_60:  1
# [3.95]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [38.3]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes aos meses de dezembro de 2018 a maio de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.']
# ++++++++++++++++++
# cidade:  1
# ['Salvador']
# ++++++++++++++++++
# estado:  1
# ['Bahia']
# ++++++++++++++++++
# região:  1
# ['Nordeste']
# ++++++++++++++++++
# sistema:  1
# ['Bike Salvador']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [50.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [400.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [1284.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [8263.34]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [28.55]
# ++++++++++++++++++
# homens:  1
# [65.83]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [40.61]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [51.13]
# ++++++++++++++++++
# acima_de_60:  1
# [3.95]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [38.3]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes aos meses de dezembro de 2018 a maio de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.']
# ++++++++++++++++++
# cidade:  1
# ['Salvador']
# ++++++++++++++++++
# estado:  1
# ['Bahia']
# ++++++++++++++++++
# região:  1
# ['Nordeste']
# ++++++++++++++++++
# sistema:  1
# ['Bike Salvador']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [50.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [400.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# ...
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [20.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [200.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [2059.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [10686.35]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [30.91]
# ++++++++++++++++++
# homens:  1
# [59.6]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [37.46]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [47.25]
# ++++++++++++++++++
# acima_de_60:  1
# [3.24]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [71.3]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes aos meses de dezembro de 2018 a maio de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.\n']
# ++++++++++++++++++
# cidade:  1
# ['Vila Velha']
# ++++++++++++++++++
# estado:  1
# ['Espírito Santo']
# ++++++++++++++++++
# região:  1
# ['Sudeste']
# ++++++++++++++++++
# sistema:  1
# ['Bike VV']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [20.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [200.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [2059.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [10686.35]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [30.91]
# ++++++++++++++++++
# homens:  1
# [59.6]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [37.46]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [47.25]
# ++++++++++++++++++
# acima_de_60:  1
# [3.24]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [71.3]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes aos meses de dezembro de 2018 a maio de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.\n']
# ++++++++++++++++++
# cidade:  1
# ['Vila Velha']
# ++++++++++++++++++
# estado:  1
# ['Espírito Santo']
# ++++++++++++++++++
# região:  1
# ['Sudeste']
# ++++++++++++++++++
# sistema:  1
# ['Bike VV']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [20.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [200.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [2059.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [10686.35]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [30.91]
# ++++++++++++++++++
# homens:  1
# [59.6]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [37.46]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [47.25]
# ++++++++++++++++++
# acima_de_60:  1
# [3.24]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [71.3]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes aos meses de dezembro de 2018 a maio de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.\n']
# ++++++++++++++++++
# cidade:  1
# ['Vila Velha']
# ++++++++++++++++++
# estado:  1
# ['Espírito Santo']
# ++++++++++++++++++
# região:  1
# ['Sudeste']
# ++++++++++++++++++
# sistema:  1
# ['Bike VV']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [20.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [200.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [2059.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [10686.35]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [30.91]
# ++++++++++++++++++
# homens:  1
# [59.6]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [37.46]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [47.25]
# ++++++++++++++++++
# acima_de_60:  1
# [3.24]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [71.3]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes aos meses de dezembro de 2018 a maio de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.\n']
# ++++++++++++++++++
# cidade:  1
# ['Vila Velha']
# ++++++++++++++++++
# estado:  1
# ['Espírito Santo']
# ++++++++++++++++++
# região:  1
# ['Sudeste']
# ++++++++++++++++++
# sistema:  1
# ['Bike VV']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [20.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [200.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [2059.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [10686.35]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [30.91]
# ++++++++++++++++++
# homens:  1
# [59.6]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [37.46]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [47.25]
# ++++++++++++++++++
# acima_de_60:  1
# [3.24]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [71.3]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes aos meses de dezembro de 2018 a maio de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.\n']
# ++++++++++++++++++
# Bicicleta
# Patinete Eletrico
# cidade:  1
# ['Vila Velha']
# ++++++++++++++++++
# estado:  1
# ['Espírito Santo']
# ++++++++++++++++++
# região:  1
# ['Sudeste']
# ++++++++++++++++++
# sistema:  1
# ['Bike VV']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [20.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [200.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [2059.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [10686.35]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [30.91]
# ++++++++++++++++++
# homens:  1
# [59.6]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [37.46]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [47.25]
# ++++++++++++++++++
# acima_de_60:  1
# [3.24]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [71.3]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes aos meses de dezembro de 2018 a maio de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.\n']
# ++++++++++++++++++
# cidade:  1
# ['Vila Velha']
# ++++++++++++++++++
# estado:  1
# ['Espírito Santo']
# ++++++++++++++++++
# região:  1
# ['Sudeste']
# ++++++++++++++++++
# sistema:  1
# ['Bike VV']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [20.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [200.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [2059.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [10686.35]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [30.91]
# ++++++++++++++++++
# homens:  1
# [59.6]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [37.46]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [47.25]
# ++++++++++++++++++
# acima_de_60:  1
# [3.24]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [71.3]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes aos meses de dezembro de 2018 a maio de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.\n']
# ++++++++++++++++++
# cidade:  1
# ['Vila Velha']
# ++++++++++++++++++
# estado:  1
# ['Espírito Santo']
# ++++++++++++++++++
# região:  1
# ['Sudeste']
# ++++++++++++++++++
# sistema:  1
# ['Bike VV']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [20.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [200.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [2059.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [10686.35]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [30.91]
# ++++++++++++++++++
# homens:  1
# [59.6]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [37.46]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [47.25]
# ++++++++++++++++++
# acima_de_60:  1
# [3.24]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [71.3]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes aos meses de dezembro de 2018 a maio de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.\n']
# ++++++++++++++++++
# cidade:  1
# ['Vila Velha']
# ++++++++++++++++++
# estado:  1
# ['Espírito Santo']
# ++++++++++++++++++
# região:  1
# ['Sudeste']
# ++++++++++++++++++
# sistema:  1
# ['Bike VV']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [20.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [200.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [2059.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [10686.35]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [30.91]
# ++++++++++++++++++
# homens:  1
# [59.6]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [37.46]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [47.25]
# ++++++++++++++++++
# acima_de_60:  1
# [3.24]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [71.3]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes aos meses de dezembro de 2018 a maio de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.\n']
# ++++++++++++++++++
# cidade:  1
# ['Vila Velha']
# ++++++++++++++++++
# estado:  1
# ['Espírito Santo']
# ++++++++++++++++++
# região:  1
# ['Sudeste']
# ++++++++++++++++++
# sistema:  1
# ['Bike VV']
# ++++++++++++++++++
# operadora:  1
# ['Tembici']
# ++++++++++++++++++
# tipologia_do_veículo:  1
# ['Bicicleta']
# ++++++++++++++++++
# estações:  1
# [20.]
# ++++++++++++++++++
# bicicletas_elétricas:  1
# [nan]
# ++++++++++++++++++
# bicicletas:  1
# [200.]
# ++++++++++++++++++
# patinetes_elétricos:  1
# [nan]
# ++++++++++++++++++
# viagens_diárias:  1
# [2059.]
# ++++++++++++++++++
# média_distância_percorrida_por_dia:  1
# [10686.35]
# ++++++++++++++++++
# usuários:  1
# [nan]
# ++++++++++++++++++
# mulheres:  1
# [30.91]
# ++++++++++++++++++
# homens:  1
# [59.6]
# ++++++++++++++++++
# 15_até_29_anos:  1
# [37.46]
# ++++++++++++++++++
# 30_até_59_anos:  1
# [47.25]
# ++++++++++++++++++
# acima_de_60:  1
# [3.24]
# ++++++++++++++++++
# emissões_de_co2_evitadas:  1
# [71.3]
# ++++++++++++++++++
# fonte_e_escopo_temporal:  1
# ['Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes aos meses de dezembro de 2018 a maio de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.\n']
# ++++++++++++++++++
# Vitória
# Vitória Espírito Santo
# Bicicleta
# Patinete Eletrico

# %%
dicionario_final
# Out:
# {'15_até_29_anos': 8.932864539204003e+33,
#  '30_até_59_anos': 4.87806267592609e+34,
#  'acima_de_60': 0.0,
#  'bicicletas': 10520.0,
#  'bicicletas_elétricas': 'Dados não disponíveis',
#  'emissões_de_co2_evitadas': 552.77,
#  'estações': 1004.0,
#  'homens': 5.497163133710966e+34,
#  'local': 'Brasil',
#  'mulheres': 1.3587294996414433e+34,
#  'municipios': [{'15_até_29_anos': 'Dados não disponíveis',
#    '30_até_59_anos': 'Dados não disponíveis',
#    'acima_de_60': 'Dados não disponíveis',
#    'bicicletas': 'Dados não disponíveis',
#    'bicicletas_elétricas': 'Dados não disponíveis',
#    'cidade': 'Belém',
#    'emissões_de_co2_evitadas': 'Dados não disponíveis',
#    'estado': 0    Pará
#    Name: estado, dtype: object,
#    'estações': 'Dados não disponíveis',
#    'homens': 'Dados não disponíveis',
#    'lat': Series([], Name: latitude, dtype: float64),
#    'long': Series([], Name: longitude, dtype: float64),
#    'modais': [{'15_até_29_anos': 'Dados não disponíveis',
#      '30_até_59_anos': 'Dados não disponíveis',
#      'acima_de_60': 'Dados não disponíveis',
#      'bicicletas': 'Dados não disponíveis',
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Belém',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 'Dados não disponíveis',
#      'homens': 'Dados não disponíveis',
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 'Dados não disponíveis',
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'tipologia_do_veículo': 'Bicicleta',
#      'usuários': 'Dados não disponíveis',
#      'viagens_diárias': 'Dados não disponíveis'}],
#    'mulheres': 'Dados não disponíveis',
#    'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#    'patinetes_elétricos': 'Dados não disponíveis',
#    'sistemas': [{'15_até_29_anos': 'Dados não disponíveis',
#      '30_até_59_anos': 'Dados não disponíveis',
#      'acima_de_60': 'Dados não disponíveis',
#      'bicicletas': 'Dados não disponíveis',
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Belém',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 'Dados não disponíveis',
#      'homens': 'Dados não disponíveis',
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 'Dados não disponíveis',
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'sistema': 'Bike Belém',
#      'usuários': 'Dados não disponíveis',
#      'veiculos': [{'15_até_29_anos': nan,
#        '30_até_59_anos': nan,
#        'acima_de_60': nan,
#        'bicicletas': nan,
#        'bicicletas_elétricas': nan,
#        'cidade': 'Belém',
#        'emissões_de_co2_evitadas': nan,
#        'estado': 'Pará',
#        'estações': nan,
#        'fonte_e_escopo_temporal': nan,
#        'homens': nan,
#        'lat': Series([], Name: latitude, dtype: float64),
#        'long': Series([], Name: longitude, dtype: float64),
#        'mulheres': nan,
#        'média_distância_percorrida_por_dia': nan,
#        'operadora': 'Tembici',
#        'patinetes_elétricos': nan,
#        'região': 'Norte',
#        'sistema': 'Bike Belém',
#        'tipologia_do_veículo': 'Bicicleta',
#        'usuários': nan,
#        'viagens_diárias': nan}],
#      'viagens_diárias': 'Dados não disponíveis'}],
#    'usuários': 'Dados não disponíveis',
#    'viagens_diárias': 'Dados não disponíveis'},
#   {'15_até_29_anos': 'Dados não disponíveis',
#    '30_até_59_anos': 'Dados não disponíveis',
#    'acima_de_60': 'Dados não disponíveis',
#    'bicicletas': 140.0,
#    'bicicletas_elétricas': 'Dados não disponíveis',
#    'cidade': 'Belo Horizonte',
#    'emissões_de_co2_evitadas': 'Dados não disponíveis',
#    'estado': 1    Minas Gerais
#    2    Minas Gerais
#    3    Minas Gerais
#    Name: estado, dtype: object,
#    'estações': 14.0,
#    'homens': 'Dados não disponíveis',
#    'lat': Series([], Name: latitude, dtype: float64),
#    'long': Series([], Name: longitude, dtype: float64),
#    'modais': [{'15_até_29_anos': 'Dados não disponíveis',
#      '30_até_59_anos': 'Dados não disponíveis',
#      'acima_de_60': 'Dados não disponíveis',
#      'bicicletas': 140.0,
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Belo Horizonte',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 14.0,
#      'homens': 'Dados não disponíveis',
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 'Dados não disponíveis',
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'tipologia_do_veículo': 'Bicicleta',
#      'usuários': 1049.0,
#      'viagens_diárias': 158.0},
#     {'15_até_29_anos': 'Dados não disponíveis',
#      '30_até_59_anos': 'Dados não disponíveis',
#      'acima_de_60': 'Dados não disponíveis',
#      'bicicletas': 'Dados não disponíveis',
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Belo Horizonte',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 'Dados não disponíveis',
#      'homens': 'Dados não disponíveis',
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 'Dados não disponíveis',
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'tipologia_do_veículo': 'Patinete Eletrico',
#      'usuários': 'Dados não disponíveis',
#      'viagens_diárias': 'Dados não disponíveis'}],
#    'mulheres': 'Dados não disponíveis',
#    'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#    'patinetes_elétricos': 'Dados não disponíveis',
#    'sistemas': [{'15_até_29_anos': 43.37,
#      '30_até_59_anos': 54.62,
#      'acima_de_60': 2.0,
#      'bicicletas': 140.0,
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Belo Horizonte',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 14.0,
#      'homens': 54.43,
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 45.57,
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'sistema': 'Bike BH',
#      'usuários': 1049.0,
#      'veiculos': [{'15_até_29_anos': 43.37,
#        '30_até_59_anos': 54.62,
#        'acima_de_60': 2.0,
#        'bicicletas': 140.0,
#        'bicicletas_elétricas': nan,
#        'cidade': 'Belo Horizonte',
#        'emissões_de_co2_evitadas': nan,
#        'estado': 'Minas Gerais',
#        'estações': 14.0,
#        'fonte_e_escopo_temporal': 'Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias,  nº de usuários, sexo e idade: Calculados com base nos dados fornecidos em dezembro de 2019 pela operadora Serttel sobre o sistema, referentes aos meses de abril de 2019 a setembro de 2019. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.',
#        'homens': 54.43,
#        'lat': Series([], Name: latitude, dtype: float64),
#        'long': Series([], Name: longitude, dtype: float64),
#        'mulheres': 45.57,
#        'média_distância_percorrida_por_dia': nan,
#        'operadora': 'Serttel',
#        'patinetes_elétricos': nan,
#        'região': 'Sudeste',
#        'sistema': 'Bike BH',
#        'tipologia_do_veículo': 'Bicicleta',
#        'usuários': 1049.0,
#        'viagens_diárias': 158.0}],
#      'viagens_diárias': 158.0},
#     {'15_até_29_anos': 'Dados não disponíveis',
#      '30_até_59_anos': 'Dados não disponíveis',
#      'acima_de_60': 'Dados não disponíveis',
#      'bicicletas': 'Dados não disponíveis',
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Belo Horizonte',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 'Dados não disponíveis',
#      'homens': 'Dados não disponíveis',
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 'Dados não disponíveis',
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'sistema': 'Yellow',
#      'usuários': 'Dados não disponíveis',
#      'veiculos': [{'15_até_29_anos': nan,
#        '30_até_59_anos': nan,
#        'acima_de_60': nan,
#        'bicicletas': nan,
#        'bicicletas_elétricas': nan,
#        'cidade': 'Belo Horizonte',
#        'emissões_de_co2_evitadas': nan,
#        'estado': 'Minas Gerais',
#        'estações': nan,
#        'fonte_e_escopo_temporal': nan,
#        'homens': nan,
#        'lat': Series([], Name: latitude, dtype: float64),
#        'long': Series([], Name: longitude, dtype: float64),
#        'mulheres': nan,
#        'média_distância_percorrida_por_dia': nan,
#        'operadora': 'Yellow',
#        'patinetes_elétricos': nan,
#        'região': 'Sudeste',
#        'sistema': 'Yellow',
#        'tipologia_do_veículo': 'Bicicleta',
#        'usuários': nan,
#        'viagens_diárias': nan},
#       {'15_até_29_anos': nan,
#        '30_até_59_anos': nan,
#        'acima_de_60': nan,
#        'bicicletas': nan,
#        'bicicletas_elétricas': nan,
#        'cidade': 'Belo Horizonte',
#        'emissões_de_co2_evitadas': nan,
#        'estado': 'Minas Gerais',
#        'estações': nan,
#        'fonte_e_escopo_temporal': nan,
#        'homens': nan,
#        'lat': Series([], Name: latitude, dtype: float64),
#        'long': Series([], Name: longitude, dtype: float64),
#        'mulheres': nan,
#        'média_distância_percorrida_por_dia': nan,
#        'operadora': 'Yellow',
#        'patinetes_elétricos': nan,
#        'região': 'Sudeste',
#        'sistema': 'Yellow',
#        'tipologia_do_veículo': 'Patinete Eletrico',
#        'usuários': nan,
#        'viagens_diárias': nan}],
#      'viagens_diárias': 'Dados não disponíveis'}],
#    'usuários': 1049.0,
#    'viagens_diárias': 158.0},
#   {'15_até_29_anos': 'Dados não disponíveis',
#    '30_até_59_anos': 'Dados não disponíveis',
#    'acima_de_60': 'Dados não disponíveis',
#    'bicicletas': 'Dados não disponíveis',
#    'bicicletas_elétricas': 'Dados não disponíveis',
#    'cidade': 'Bertioga',
#    'emissões_de_co2_evitadas': 'Dados não disponíveis',
#    'estado': 4    São Paulo
#    Name: estado, dtype: object,
#    'estações': 'Dados não disponíveis',
#    'homens': 'Dados não disponíveis',
#    'lat': Series([], Name: latitude, dtype: float64),
#    'long': Series([], Name: longitude, dtype: float64),
#    'modais': [{'15_até_29_anos': 'Dados não disponíveis',
#      '30_até_59_anos': 'Dados não disponíveis',
#      'acima_de_60': 'Dados não disponíveis',
#      'bicicletas': 'Dados não disponíveis',
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Bertioga',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 'Dados não disponíveis',
#      'homens': 'Dados não disponíveis',
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 'Dados não disponíveis',
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'tipologia_do_veículo': 'Bicicleta',
#      'usuários': 'Dados não disponíveis',
#      'viagens_diárias': 'Dados não disponíveis'}],
#    'mulheres': 'Dados não disponíveis',
#    'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#    'patinetes_elétricos': 'Dados não disponíveis',
#    'sistemas': [{'15_até_29_anos': 'Dados não disponíveis',
#      '30_até_59_anos': 'Dados não disponíveis',
#      'acima_de_60': 'Dados não disponíveis',
#      'bicicletas': 'Dados não disponíveis',
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Bertioga',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 'Dados não disponíveis',
#      'homens': 'Dados não disponíveis',
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 'Dados não disponíveis',
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'sistema': 'Rivibike',
#      'usuários': 'Dados não disponíveis',
#      'veiculos': [{'15_até_29_anos': nan,
#        '30_até_59_anos': nan,
#        'acima_de_60': nan,
#        'bicicletas': nan,
#        'bicicletas_elétricas': nan,
#        'cidade': 'Bertioga',
#        'emissões_de_co2_evitadas': nan,
#        'estado': 'São Paulo',
#        'estações': nan,
#        'fonte_e_escopo_temporal': nan,
#        'homens': nan,
#        'lat': Series([], Name: latitude, dtype: float64),
#        'long': Series([], Name: longitude, dtype: float64),
#        'mulheres': nan,
#        'média_distância_percorrida_por_dia': nan,
#        'operadora': 'Tembici',
#        'patinetes_elétricos': nan,
#        'região': 'Sudeste',
#        'sistema': 'Rivibike',
#        'tipologia_do_veículo': 'Bicicleta',
#        'usuários': nan,
#        'viagens_diárias': nan}],
#      'viagens_diárias': 'Dados não disponíveis'}],
#    'usuários': 'Dados não disponíveis',
#    'viagens_diárias': 'Dados não disponíveis'},
#   {'15_até_29_anos': 'Dados não disponíveis',
#    '30_até_59_anos': 'Dados não disponíveis',
#    'acima_de_60': 'Dados não disponíveis',
#    'bicicletas': 500.0,
#    'bicicletas_elétricas': 'Dados não disponíveis',
#    'cidade': 'Brasília',
#    'emissões_de_co2_evitadas': 'Dados não disponíveis',
#    'estado': 5    Distrito Federal
#    6    Distrito Federal
#    Name: estado, dtype: object,
#    'estações': 50.0,
#    'homens': 'Dados não disponíveis',
#    'lat': Series([], Name: latitude, dtype: float64),
#    'long': Series([], Name: longitude, dtype: float64),
#    'modais': [{'15_até_29_anos': 51.89,
#      '30_até_59_anos': 46.7,
#      'acima_de_60': 1.41,
#      'bicicletas': 500.0,
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Brasília',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 50.0,
#      'homens': 59.56,
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 40.44,
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'tipologia_do_veículo': 'Bicicleta',
#      'usuários': 36665.0,
#      'viagens_diárias': 830.0},
#     {'15_até_29_anos': 'Dados não disponíveis',
#      '30_até_59_anos': 'Dados não disponíveis',
#      'acima_de_60': 'Dados não disponíveis',
#      'bicicletas': 'Dados não disponíveis',
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Brasília',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 'Dados não disponíveis',
#      'homens': 'Dados não disponíveis',
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 'Dados não disponíveis',
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'tipologia_do_veículo': 'Patinete Eletrico',
#      'usuários': 'Dados não disponíveis',
#      'viagens_diárias': 'Dados não disponíveis'}],
#    'mulheres': 'Dados não disponíveis',
#    'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#    'patinetes_elétricos': 'Dados não disponíveis',
#    'sistemas': [{'15_até_29_anos': 51.89,
#      '30_até_59_anos': 46.7,
#      'acima_de_60': 1.41,
#      'bicicletas': 500.0,
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Brasília',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 50.0,
#      'homens': 59.56,
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 40.44,
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'sistema': 'Mais Bike',
#      'usuários': 36665.0,
#      'veiculos': [{'15_até_29_anos': 51.89,
#        '30_até_59_anos': 46.7,
#        'acima_de_60': 1.41,
#        'bicicletas': 500.0,
#        'bicicletas_elétricas': nan,
#        'cidade': 'Brasília',
#        'emissões_de_co2_evitadas': nan,
#        'estado': 'Distrito Federal',
#        'estações': 50.0,
#        'fonte_e_escopo_temporal': 'Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias,  nº de usuários, sexo e idade: Calculados com base nos dados fornecidos em dezembro de 2019 pela operadora Serttel sobre o sistema, referentes aos meses de abril de 2019 a setembro de 2019. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.',
#        'homens': 59.56,
#        'lat': Series([], Name: latitude, dtype: float64),
#        'long': Series([], Name: longitude, dtype: float64),
#        'mulheres': 40.44,
#        'média_distância_percorrida_por_dia': nan,
#        'operadora': 'Serttel',
#        'patinetes_elétricos': nan,
#        'região': 'Centro-Oeste',
#        'sistema': 'Mais Bike',
#        'tipologia_do_veículo': 'Bicicleta',
#        'usuários': 36665.0,
#        'viagens_diárias': 830.0}],
#      'viagens_diárias': 830.0},
#     {'15_até_29_anos': 'Dados não disponíveis',
#      '30_até_59_anos': 'Dados não disponíveis',
#      'acima_de_60': 'Dados não disponíveis',
#      'bicicletas': 'Dados não disponíveis',
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Brasília',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 'Dados não disponíveis',
#      'homens': 'Dados não disponíveis',
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 'Dados não disponíveis',
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'sistema': 'Yellow',
#      'usuários': 'Dados não disponíveis',
#      'veiculos': [{'15_até_29_anos': nan,
#        '30_até_59_anos': nan,
#        'acima_de_60': nan,
#        'bicicletas': nan,
#        'bicicletas_elétricas': nan,
#        'cidade': 'Brasília',
#        'emissões_de_co2_evitadas': nan,
#        'estado': 'Distrito Federal',
#        'estações': nan,
#        'fonte_e_escopo_temporal': nan,
#        'homens': nan,
#        'lat': Series([], Name: latitude, dtype: float64),
#        'long': Series([], Name: longitude, dtype: float64),
#        'mulheres': nan,
#        'média_distância_percorrida_por_dia': nan,
#        'operadora': 'Yellow',
#        'patinetes_elétricos': nan,
#        'região': 'Centro-Oeste',
#        'sistema': 'Yellow',
#        'tipologia_do_veículo': 'Patinete Eletrico',
#        'usuários': nan,
#        'viagens_diárias': nan}],
#      'viagens_diárias': 'Dados não disponíveis'}],
#    'usuários': 36665.0,
#    'viagens_diárias': 830.0},
#   {'15_até_29_anos': 'Dados não disponíveis',
#    '30_até_59_anos': 'Dados não disponíveis',
#    'acima_de_60': 'Dados não disponíveis',
#    'bicicletas': 'Dados não disponíveis',
#    'bicicletas_elétricas': 'Dados não disponíveis',
#    'cidade': 'Campinas',
#    'emissões_de_co2_evitadas': 'Dados não disponíveis',
#    'estado': 7    São Paulo
#    8    São Paulo
#    Name: estado, dtype: object,
#    'estações': 'Dados não disponíveis',
#    'homens': 'Dados não disponíveis',
#    'lat': Series([], Name: latitude, dtype: float64),
#    'long': Series([], Name: longitude, dtype: float64),
#    'modais': [{'15_até_29_anos': 'Dados não disponíveis',
#      '30_até_59_anos': 'Dados não disponíveis',
#      'acima_de_60': 'Dados não disponíveis',
#      'bicicletas': 'Dados não disponíveis',
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Campinas',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 'Dados não disponíveis',
#      'homens': 'Dados não disponíveis',
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 'Dados não disponíveis',
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'tipologia_do_veículo': 'Bicicleta',
#      'usuários': 'Dados não disponíveis',
#      'viagens_diárias': 'Dados não disponíveis'},
#     {'15_até_29_anos': 'Dados não disponíveis',
#      '30_até_59_anos': 'Dados não disponíveis',
#      'acima_de_60': 'Dados não disponíveis',
#      'bicicletas': 'Dados não disponíveis',
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Campinas',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 'Dados não disponíveis',
#      'homens': 'Dados não disponíveis',
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 'Dados não disponíveis',
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'tipologia_do_veículo': 'Patinete Eletrico',
#      'usuários': 'Dados não disponíveis',
#      'viagens_diárias': 'Dados não disponíveis'}],
#    'mulheres': 'Dados não disponíveis',
#    'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#    'patinetes_elétricos': 'Dados não disponíveis',
#    'sistemas': [{'15_até_29_anos': 'Dados não disponíveis',
#      '30_até_59_anos': 'Dados não disponíveis',
#      'acima_de_60': 'Dados não disponíveis',
#      'bicicletas': 'Dados não disponíveis',
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Campinas',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 'Dados não disponíveis',
#      'homens': 'Dados não disponíveis',
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 'Dados não disponíveis',
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'sistema': 'Yellow',
#      'usuários': 'Dados não disponíveis',
#      'veiculos': [{'15_até_29_anos': nan,
#        '30_até_59_anos': nan,
#        'acima_de_60': nan,
#        'bicicletas': nan,
#        'bicicletas_elétricas': nan,
#        'cidade': 'Campinas',
#        'emissões_de_co2_evitadas': nan,
#        'estado': 'São Paulo',
#        'estações': nan,
#        'fonte_e_escopo_temporal': nan,
#        'homens': nan,
#        'lat': Series([], Name: latitude, dtype: float64),
#        'long': Series([], Name: longitude, dtype: float64),
#        'mulheres': nan,
#        'média_distância_percorrida_por_dia': nan,
#        'operadora': 'Yellow',
#        'patinetes_elétricos': nan,
#        'região': 'Sudeste',
#        'sistema': 'Yellow',
#        'tipologia_do_veículo': 'Bicicleta',
#        'usuários': nan,
#        'viagens_diárias': nan},
#       {'15_até_29_anos': nan,
#        '30_até_59_anos': nan,
#        'acima_de_60': nan,
#        'bicicletas': nan,
#        'bicicletas_elétricas': nan,
#        'cidade': 'Campinas',
#        'emissões_de_co2_evitadas': nan,
#        'estado': 'São Paulo',
#        'estações': nan,
#        'fonte_e_escopo_temporal': nan,
#        'homens': nan,
#        'lat': Series([], Name: latitude, dtype: float64),
#        'long': Series([], Name: longitude, dtype: float64),
#        'mulheres': nan,
#        'média_distância_percorrida_por_dia': nan,
#        'operadora': 'Yellow',
#        'patinetes_elétricos': nan,
#        'região': 'Sudeste',
#        'sistema': 'Yellow',
#        'tipologia_do_veículo': 'Patinete Eletrico',
#        'usuários': nan,
#        'viagens_diárias': nan}],
#      'viagens_diárias': 'Dados não disponíveis'}],
#    'usuários': 'Dados não disponíveis',
#    'viagens_diárias': 'Dados não disponíveis'},
#   {'15_até_29_anos': 'Dados não disponíveis',
#    '30_até_59_anos': 'Dados não disponíveis',
#    'acima_de_60': 'Dados não disponíveis',
#    'bicicletas': 'Dados não disponíveis',
#    'bicicletas_elétricas': 'Dados não disponíveis',
#    'cidade': 'Curitiba',
#    'emissões_de_co2_evitadas': 'Dados não disponíveis',
#    'estado': 9     Paraná
#    10    Paraná
#    Name: estado, dtype: object,
#    'estações': 'Dados não disponíveis',
#    'homens': 'Dados não disponíveis',
#    'lat': Series([], Name: latitude, dtype: float64),
#    'long': Series([], Name: longitude, dtype: float64),
#    'modais': [{'15_até_29_anos': 'Dados não disponíveis',
#      '30_até_59_anos': 'Dados não disponíveis',
#      'acima_de_60': 'Dados não disponíveis',
#      'bicicletas': 'Dados não disponíveis',
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Curitiba',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 'Dados não disponíveis',
#      'homens': 'Dados não disponíveis',
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 'Dados não disponíveis',
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'tipologia_do_veículo': 'Bicicleta',
#      'usuários': 'Dados não disponíveis',
#      'viagens_diárias': 'Dados não disponíveis'},
#     {'15_até_29_anos': 'Dados não disponíveis',
#      '30_até_59_anos': 'Dados não disponíveis',
#      'acima_de_60': 'Dados não disponíveis',
#      'bicicletas': 'Dados não disponíveis',
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Curitiba',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 'Dados não disponíveis',
#      'homens': 'Dados não disponíveis',
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 'Dados não disponíveis',
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'tipologia_do_veículo': 'Patinete Eletrico',
#      'usuários': 'Dados não disponíveis',
#      'viagens_diárias': 'Dados não disponíveis'}],
#    'mulheres': 'Dados não disponíveis',
#    'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#    'patinetes_elétricos': 'Dados não disponíveis',
#    'sistemas': [{'15_até_29_anos': 'Dados não disponíveis',
#      '30_até_59_anos': 'Dados não disponíveis',
#      'acima_de_60': 'Dados não disponíveis',
#      'bicicletas': 'Dados não disponíveis',
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Curitiba',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 'Dados não disponíveis',
#      'homens': 'Dados não disponíveis',
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 'Dados não disponíveis',
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'sistema': 'Yellow',
#      'usuários': 'Dados não disponíveis',
#      'veiculos': [{'15_até_29_anos': nan,
#        '30_até_59_anos': nan,
#        'acima_de_60': nan,
#        'bicicletas': nan,
#        'bicicletas_elétricas': nan,
#        'cidade': 'Curitiba',
#        'emissões_de_co2_evitadas': nan,
#        'estado': 'Paraná',
#        'estações': nan,
#        'fonte_e_escopo_temporal': nan,
#        'homens': nan,
#        'lat': Series([], Name: latitude, dtype: float64),
#        'long': Series([], Name: longitude, dtype: float64),
#        'mulheres': nan,
#        'média_distância_percorrida_por_dia': nan,
#        'operadora': 'Yellow',
#        'patinetes_elétricos': nan,
#        'região': 'Sul',
#        'sistema': 'Yellow',
#        'tipologia_do_veículo': 'Bicicleta',
#        'usuários': nan,
#        'viagens_diárias': nan},
#       {'15_até_29_anos': nan,
#        '30_até_59_anos': nan,
#        'acima_de_60': nan,
#        'bicicletas': nan,
#        'bicicletas_elétricas': nan,
#        'cidade': 'Curitiba',
#        'emissões_de_co2_evitadas': nan,
#        'estado': 'Paraná',
#        'estações': nan,
#        'fonte_e_escopo_temporal': nan,
#        'homens': nan,
#        'lat': Series([], Name: latitude, dtype: float64),
#        'long': Series([], Name: longitude, dtype: float64),
#        'mulheres': nan,
#        'média_distância_percorrida_por_dia': nan,
#        'operadora': 'Yellow',
#        'patinetes_elétricos': nan,
#        'região': 'Sul',
#        'sistema': 'Yellow',
#        'tipologia_do_veículo': 'Patinete Eletrico',
#        'usuários': nan,
#        'viagens_diárias': nan}],
#      'viagens_diárias': 'Dados não disponíveis'}],
#    'usuários': 'Dados não disponíveis',
#    'viagens_diárias': 'Dados não disponíveis'},
#   {'15_até_29_anos': 'Dados não disponíveis',
#    '30_até_59_anos': 'Dados não disponíveis',
#    'acima_de_60': 'Dados não disponíveis',
#    'bicicletas': 'Dados não disponíveis',
#    'bicicletas_elétricas': 'Dados não disponíveis',
#    'cidade': 'Florianópolis',
#    'emissões_de_co2_evitadas': 'Dados não disponíveis',
#    'estado': 11    Santa Catarina
#    12    Santa Catarina
#    Name: estado, dtype: object,
#    'estações': 'Dados não disponíveis',
#    'homens': 'Dados não disponíveis',
#    'lat': Series([], Name: latitude, dtype: float64),
#    'long': Series([], Name: longitude, dtype: float64),
#    'modais': [{'15_até_29_anos': 'Dados não disponíveis',
#      '30_até_59_anos': 'Dados não disponíveis',
#      'acima_de_60': 'Dados não disponíveis',
#      'bicicletas': 'Dados não disponíveis',
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Florianópolis',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 'Dados não disponíveis',
#      'homens': 'Dados não disponíveis',
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 'Dados não disponíveis',
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'tipologia_do_veículo': 'Bicicleta',
#      'usuários': 'Dados não disponíveis',
#      'viagens_diárias': 'Dados não disponíveis'},
#     {'15_até_29_anos': 'Dados não disponíveis',
#      '30_até_59_anos': 'Dados não disponíveis',
#      'acima_de_60': 'Dados não disponíveis',
#      'bicicletas': 'Dados não disponíveis',
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Florianópolis',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 'Dados não disponíveis',
#      'homens': 'Dados não disponíveis',
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 'Dados não disponíveis',
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'tipologia_do_veículo': 'Patinete Eletrico',
#      'usuários': 'Dados não disponíveis',
#      'viagens_diárias': 'Dados não disponíveis'}],
#    'mulheres': 'Dados não disponíveis',
#    'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#    'patinetes_elétricos': 'Dados não disponíveis',
#    'sistemas': [{'15_até_29_anos': 'Dados não disponíveis',
#      '30_até_59_anos': 'Dados não disponíveis',
#      'acima_de_60': 'Dados não disponíveis',
#      'bicicletas': 'Dados não disponíveis',
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Florianópolis',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 'Dados não disponíveis',
#      'homens': 'Dados não disponíveis',
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 'Dados não disponíveis',
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'sistema': 'Yellow',
#      'usuários': 'Dados não disponíveis',
#      'veiculos': [{'15_até_29_anos': nan,
#        '30_até_59_anos': nan,
#        'acima_de_60': nan,
#        'bicicletas': nan,
#        'bicicletas_elétricas': nan,
#        'cidade': 'Florianópolis',
#        'emissões_de_co2_evitadas': nan,
#        'estado': 'Santa Catarina',
#        'estações': nan,
#        'fonte_e_escopo_temporal': nan,
#        'homens': nan,
#        'lat': Series([], Name: latitude, dtype: float64),
#        'long': Series([], Name: longitude, dtype: float64),
#        'mulheres': nan,
#        'média_distância_percorrida_por_dia': nan,
#        'operadora': 'Yellow',
#        'patinetes_elétricos': nan,
#        'região': 'Sul',
#        'sistema': 'Yellow',
#        'tipologia_do_veículo': 'Bicicleta',
#        'usuários': nan,
#        'viagens_diárias': nan},
#       {'15_até_29_anos': nan,
#        '30_até_59_anos': nan,
#        'acima_de_60': nan,
#        'bicicletas': nan,
#        'bicicletas_elétricas': nan,
#        'cidade': 'Florianópolis',
#        'emissões_de_co2_evitadas': nan,
#        'estado': 'Santa Catarina',
#        'estações': nan,
#        'fonte_e_escopo_temporal': nan,
#        'homens': nan,
#        'lat': Series([], Name: latitude, dtype: float64),
#        'long': Series([], Name: longitude, dtype: float64),
#        'mulheres': nan,
#        'média_distância_percorrida_por_dia': nan,
#        'operadora': 'Yellow',
#        'patinetes_elétricos': nan,
#        'região': 'Sul',
#        'sistema': 'Yellow',
#        'tipologia_do_veículo': 'Patinete Eletrico',
#        'usuários': nan,
#        'viagens_diárias': nan}],
#      'viagens_diárias': 'Dados não disponíveis'}],
#    'usuários': 'Dados não disponíveis',
#    'viagens_diárias': 'Dados não disponíveis'},
#   {'15_até_29_anos': 0.15009005708703482,
#    '30_até_59_anos': 0.1475104557804439,
#    'acima_de_60': 0.007662484354489117,
#    'bicicletas': 1200.0,
#    'bicicletas_elétricas': 'Dados não disponíveis',
#    'cidade': 'Fortaleza',
#    'emissões_de_co2_evitadas': 'Dados não disponíveis',
#    'estado': 13    Ceará
#    14    Ceará
#    Name: estado, dtype: object,
#    'estações': 92.0,
#    'homens': 0.1754128888481851,
#    'lat': Series([], Name: latitude, dtype: float64),
#    'long': Series([], Name: longitude, dtype: float64),
#    'modais': [{'15_até_29_anos': 0.15009005708703482,
#      '30_até_59_anos': 0.1475104557804439,
#      'acima_de_60': 0.007662484354489117,
#      'bicicletas': 1200.0,
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Fortaleza',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 92.0,
#      'homens': 0.1754128888481851,
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 0.12986537228683945,
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'tipologia_do_veículo': 'Bicicleta',
#      'usuários': 65514.0,
#      'viagens_diárias': 1445.0}],
#    'mulheres': 0.12986537228683945,
#    'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#    'patinetes_elétricos': 'Dados não disponíveis',
#    'sistemas': [{'15_até_29_anos': 33.59,
#      '30_até_59_anos': 62.81,
#      'acima_de_60': 3.59,
#      'bicicletas': 350.0,
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Fortaleza',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 7.0,
#      'homens': 64.6,
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 35.4,
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'sistema': 'Bicicleta Integrada',
#      'usuários': 8436.0,
#      'veiculos': [{'15_até_29_anos': 33.59,
#        '30_até_59_anos': 62.81,
#        'acima_de_60': 3.59,
#        'bicicletas': 350.0,
#        'bicicletas_elétricas': nan,
#        'cidade': 'Fortaleza',
#        'emissões_de_co2_evitadas': nan,
#        'estado': 'Ceará',
#        'estações': 7.0,
#        'fonte_e_escopo_temporal': 'Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias,  nº de usuários, sexo e idade: Calculados com base nos dados fornecidos em dezembro de 2019 pela operadora Serttel sobre o sistema, referentes aos meses de abril de 2019 a setembro de 2019. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.',
#        'homens': 64.6,
#        'lat': Series([], Name: latitude, dtype: float64),
#        'long': Series([], Name: longitude, dtype: float64),
#        'mulheres': 35.4,
#        'média_distância_percorrida_por_dia': nan,
#        'operadora': 'Serttel',
#        'patinetes_elétricos': nan,
#        'região': 'Nordeste',
#        'sistema': 'Bicicleta Integrada',
#        'tipologia_do_veículo': 'Bicicleta',
#        'usuários': 8436.0,
#        'viagens_diárias': 128.0}],
#      'viagens_diárias': 128.0},
#     {'15_até_29_anos': 64.74,
#      '30_até_59_anos': 33.83,
#      'acima_de_60': 1.43,
#      'bicicletas': 850.0,
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Fortaleza',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 85.0,
#      'homens': 50.32,
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 49.68,
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'sistema': 'Bicicletar',
#      'usuários': 57078.0,
#      'veiculos': [{'15_até_29_anos': 64.74,
#        '30_até_59_anos': 33.83,
#        'acima_de_60': 1.43,
#        'bicicletas': 850.0,
#        'bicicletas_elétricas': nan,
#        'cidade': 'Fortaleza',
#        'emissões_de_co2_evitadas': nan,
#        'estado': 'Ceará',
#        'estações': 85.0,
#        'fonte_e_escopo_temporal': 'Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias,  nº de usuários, sexo e idade: Calculados com base nos dados fornecidos em dezembro de 2019 pela operadora Serttel sobre o sistema, referentes aos meses de abril de 2019 a setembro de 2019. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.',
#        'homens': 50.32,
#        'lat': Series([], Name: latitude, dtype: float64),
#        'long': Series([], Name: longitude, dtype: float64),
#        'mulheres': 49.68,
#        'média_distância_percorrida_por_dia': nan,
#        'operadora': 'Serttel',
#        'patinetes_elétricos': nan,
#        'região': 'Nordeste',
#        'sistema': 'Bicicletar',
#        'tipologia_do_veículo': 'Bicicleta',
#        'usuários': 57078.0,
#        'viagens_diárias': 1317.0}],
#      'viagens_diárias': 1317.0}],
#    'usuários': 65514.0,
#    'viagens_diárias': 1445.0},
#   {'15_até_29_anos': 45.87,
#    '30_até_59_anos': 52.57,
#    'acima_de_60': 1.57,
#    'bicicletas': 200.0,
#    'bicicletas_elétricas': 'Dados não disponíveis',
#    'cidade': 'Goiânia',
#    'emissões_de_co2_evitadas': 'Dados não disponíveis',
#    'estado': 15    Goiás
#    Name: estado, dtype: object,
#    'estações': 20.0,
#    'homens': 54.81,
#    'lat': Series([], Name: latitude, dtype: float64),
#    'long': Series([], Name: longitude, dtype: float64),
#    'modais': [{'15_até_29_anos': 45.87,
#      '30_até_59_anos': 52.57,
#      'acima_de_60': 1.57,
#      'bicicletas': 200.0,
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Goiânia',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 20.0,
#      'homens': 54.81,
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 45.19,
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'tipologia_do_veículo': 'Bicicleta',
#      'usuários': 6198.0,
#      'viagens_diárias': 206.0}],
#    'mulheres': 45.19,
#    'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#    'patinetes_elétricos': 'Dados não disponíveis',
#    'sistemas': [{'15_até_29_anos': 45.87,
#      '30_até_59_anos': 52.57,
#      'acima_de_60': 1.57,
#      'bicicletas': 200.0,
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Goiânia',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 20.0,
#      'homens': 54.81,
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 45.19,
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'sistema': 'GynDebike',
#      'usuários': 6198.0,
#      'veiculos': [{'15_até_29_anos': 45.87,
#        '30_até_59_anos': 52.57,
#        'acima_de_60': 1.57,
#        'bicicletas': 200.0,
#        'bicicletas_elétricas': nan,
#        'cidade': 'Goiânia',
#        'emissões_de_co2_evitadas': nan,
#        'estado': 'Goiás',
#        'estações': 20.0,
#        'fonte_e_escopo_temporal': 'Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias,  nº de usuários, sexo e idade: Calculados com base nos dados fornecidos em dezembro de 2019 pela operadora Serttel sobre o sistema, referentes aos meses de abril de 2019 a setembro de 2019. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.',
#        'homens': 54.81,
#        'lat': Series([], Name: latitude, dtype: float64),
#        'long': Series([], Name: longitude, dtype: float64),
#        'mulheres': 45.19,
#        'média_distância_percorrida_por_dia': nan,
#        'operadora': 'Serttel',
#        'patinetes_elétricos': nan,
#        'região': 'Centro-Oeste',
#        'sistema': 'GynDebike',
#        'tipologia_do_veículo': 'Bicicleta',
#        'usuários': 6198.0,
#        'viagens_diárias': 206.0}],
#      'viagens_diárias': 206.0}],
#    'usuários': 6198.0,
#    'viagens_diárias': 206.0},
#   {'15_até_29_anos': 'Dados não disponíveis',
#    '30_até_59_anos': 'Dados não disponíveis',
#    'acima_de_60': 'Dados não disponíveis',
#    'bicicletas': 'Dados não disponíveis',
#    'bicicletas_elétricas': 'Dados não disponíveis',
#    'cidade': 'Ilhabela',
#    'emissões_de_co2_evitadas': 'Dados não disponíveis',
#    'estado': 16    São Paulo
#    Name: estado, dtype: object,
#    'estações': 'Dados não disponíveis',
#    'homens': 'Dados não disponíveis',
#    'lat': Series([], Name: latitude, dtype: float64),
#    'long': Series([], Name: longitude, dtype: float64),
#    'modais': [{'15_até_29_anos': 'Dados não disponíveis',
#      '30_até_59_anos': 'Dados não disponíveis',
#      'acima_de_60': 'Dados não disponíveis',
#      'bicicletas': 'Dados não disponíveis',
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Ilhabela',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 'Dados não disponíveis',
#      'homens': 'Dados não disponíveis',
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 'Dados não disponíveis',
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'tipologia_do_veículo': 'Bicicleta',
#      'usuários': 'Dados não disponíveis',
#      'viagens_diárias': 'Dados não disponíveis'}],
#    'mulheres': 'Dados não disponíveis',
#    'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#    'patinetes_elétricos': 'Dados não disponíveis',
#    'sistemas': [{'15_até_29_anos': 'Dados não disponíveis',
#      '30_até_59_anos': 'Dados não disponíveis',
#      'acima_de_60': 'Dados não disponíveis',
#      'bicicletas': 'Dados não disponíveis',
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Ilhabela',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 'Dados não disponíveis',
#      'homens': 'Dados não disponíveis',
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 'Dados não disponíveis',
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'sistema': 'Yellow',
#      'usuários': 'Dados não disponíveis',
#      'veiculos': [{'15_até_29_anos': nan,
#        '30_até_59_anos': nan,
#        'acima_de_60': nan,
#        'bicicletas': nan,
#        'bicicletas_elétricas': nan,
#        'cidade': 'Ilhabela',
#        'emissões_de_co2_evitadas': nan,
#        'estado': 'São Paulo',
#        'estações': nan,
#        'fonte_e_escopo_temporal': nan,
#        'homens': nan,
#        'lat': Series([], Name: latitude, dtype: float64),
#        'long': Series([], Name: longitude, dtype: float64),
#        'mulheres': nan,
#        'média_distância_percorrida_por_dia': nan,
#        'operadora': 'Yellow',
#        'patinetes_elétricos': nan,
#        'região': 'Sudeste',
#        'sistema': 'Yellow',
#        'tipologia_do_veículo': 'Bicicleta',
#        'usuários': nan,
#        'viagens_diárias': nan}],
#      'viagens_diárias': 'Dados não disponíveis'}],
#    'usuários': 'Dados não disponíveis',
#    'viagens_diárias': 'Dados não disponíveis'},
#   {'15_até_29_anos': 'Dados não disponíveis',
#    '30_até_59_anos': 'Dados não disponíveis',
#    'acima_de_60': 'Dados não disponíveis',
#    'bicicletas': 'Dados não disponíveis',
#    'bicicletas_elétricas': 'Dados não disponíveis',
#    'cidade': 'Juiz de Fora',
#    'emissões_de_co2_evitadas': 'Dados não disponíveis',
#    'estado': 17    Minas Gerais
#    Name: estado, dtype: object,
#    'estações': 'Dados não disponíveis',
#    'homens': 'Dados não disponíveis',
#    'lat': Series([], Name: latitude, dtype: float64),
#    'long': Series([], Name: longitude, dtype: float64),
#    'modais': [{'15_até_29_anos': 'Dados não disponíveis',
#      '30_até_59_anos': 'Dados não disponíveis',
#      'acima_de_60': 'Dados não disponíveis',
#      'bicicletas': 'Dados não disponíveis',
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Juiz de Fora',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 'Dados não disponíveis',
#      'homens': 'Dados não disponíveis',
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 'Dados não disponíveis',
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'tipologia_do_veículo': 'Bicicleta',
#      'usuários': 'Dados não disponíveis',
#      'viagens_diárias': 'Dados não disponíveis'}],
#    'mulheres': 'Dados não disponíveis',
#    'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#    'patinetes_elétricos': 'Dados não disponíveis',
#    'sistemas': [{'15_até_29_anos': 'Dados não disponíveis',
#      '30_até_59_anos': 'Dados não disponíveis',
#      'acima_de_60': 'Dados não disponíveis',
#      'bicicletas': 'Dados não disponíveis',
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Juiz de Fora',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 'Dados não disponíveis',
#      'homens': 'Dados não disponíveis',
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 'Dados não disponíveis',
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'sistema': 'Unimed Bike JF',
#      'usuários': 'Dados não disponíveis',
#      'veiculos': [{'15_até_29_anos': nan,
#        '30_até_59_anos': nan,
#        'acima_de_60': nan,
# ...
#    'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#    'patinetes_elétricos': 'Dados não disponíveis',
#    'sistemas': [{'15_até_29_anos': 'Dados não disponíveis',
#      '30_até_59_anos': 'Dados não disponíveis',
#      'acima_de_60': 'Dados não disponíveis',
#      'bicicletas': 'Dados não disponíveis',
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Sorocaba',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 'Dados não disponíveis',
#      'homens': 'Dados não disponíveis',
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 'Dados não disponíveis',
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'sistema': 'Integrabike',
#      'usuários': 'Dados não disponíveis',
#      'veiculos': [{'15_até_29_anos': nan,
#        '30_até_59_anos': nan,
#        'acima_de_60': nan,
#        'bicicletas': nan,
#        'bicicletas_elétricas': nan,
#        'cidade': 'Sorocaba',
#        'emissões_de_co2_evitadas': nan,
#        'estado': 'São Paulo',
#        'estações': nan,
#        'fonte_e_escopo_temporal': nan,
#        'homens': nan,
#        'lat': Series([], Name: latitude, dtype: float64),
#        'long': Series([], Name: longitude, dtype: float64),
#        'mulheres': nan,
#        'média_distância_percorrida_por_dia': nan,
#        'operadora': 'Tembici',
#        'patinetes_elétricos': nan,
#        'região': 'Sudeste',
#        'sistema': 'Integrabike',
#        'tipologia_do_veículo': 'Bicicleta',
#        'usuários': nan,
#        'viagens_diárias': nan}],
#      'viagens_diárias': 'Dados não disponíveis'}],
#    'usuários': 'Dados não disponíveis',
#    'viagens_diárias': 'Dados não disponíveis'},
#   {'15_até_29_anos': 'Dados não disponíveis',
#    '30_até_59_anos': 'Dados não disponíveis',
#    'acima_de_60': 'Dados não disponíveis',
#    'bicicletas': 200.0,
#    'bicicletas_elétricas': 'Dados não disponíveis',
#    'cidade': 'Vila Velha',
#    'emissões_de_co2_evitadas': 71.3,
#    'estado': 46    Espírito Santo
#    47    Espírito Santo
#    Name: estado, dtype: object,
#    'estações': 20.0,
#    'homens': 'Dados não disponíveis',
#    'lat': Series([], Name: latitude, dtype: float64),
#    'long': Series([], Name: longitude, dtype: float64),
#    'modais': [{'15_até_29_anos': 37.46,
#      '30_até_59_anos': 47.25,
#      'acima_de_60': 3.24,
#      'bicicletas': 200.0,
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Vila Velha',
#      'emissões_de_co2_evitadas': 71.3,
#      'estações': 20.0,
#      'homens': 59.6,
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 30.91,
#      'média_distância_percorrida_por_dia': 10686.35,
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'tipologia_do_veículo': 'Bicicleta',
#      'usuários': 'Dados não disponíveis',
#      'viagens_diárias': 2059.0},
#     {'15_até_29_anos': 'Dados não disponíveis',
#      '30_até_59_anos': 'Dados não disponíveis',
#      'acima_de_60': 'Dados não disponíveis',
#      'bicicletas': 'Dados não disponíveis',
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Vila Velha',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 'Dados não disponíveis',
#      'homens': 'Dados não disponíveis',
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 'Dados não disponíveis',
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'tipologia_do_veículo': 'Patinete Eletrico',
#      'usuários': 'Dados não disponíveis',
#      'viagens_diárias': 'Dados não disponíveis'}],
#    'mulheres': 'Dados não disponíveis',
#    'média_distância_percorrida_por_dia': 10686.35,
#    'patinetes_elétricos': 'Dados não disponíveis',
#    'sistemas': [{'15_até_29_anos': 37.46,
#      '30_até_59_anos': 47.25,
#      'acima_de_60': 3.24,
#      'bicicletas': 200.0,
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Vila Velha',
#      'emissões_de_co2_evitadas': 71.3,
#      'estações': 20.0,
#      'homens': 59.6,
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 30.91,
#      'média_distância_percorrida_por_dia': 10686.35,
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'sistema': 'Bike VV',
#      'usuários': 'Dados não disponíveis',
#      'veiculos': [{'15_até_29_anos': 37.46,
#        '30_até_59_anos': 47.25,
#        'acima_de_60': 3.24,
#        'bicicletas': 200.0,
#        'bicicletas_elétricas': nan,
#        'cidade': 'Vila Velha',
#        'emissões_de_co2_evitadas': 71.3,
#        'estado': 'Espírito Santo',
#        'estações': 20.0,
#        'fonte_e_escopo_temporal': 'Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias, distância percorrida por dia, sexo e idade: Calculados com base nos dados fornecidos em outubro de 2019 pela operadora Tembici sobre o sistema, referentes aos meses de dezembro de 2018 a maio de 2019. Os cálculos consideraram viagens a partir de cinco minutos até duas horas de duração. Sexo e idade são relativos às viagens feitas. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.\n',
#        'homens': 59.6,
#        'lat': Series([], Name: latitude, dtype: float64),
#        'long': Series([], Name: longitude, dtype: float64),
#        'mulheres': 30.91,
#        'média_distância_percorrida_por_dia': 10686.35,
#        'operadora': 'Tembici',
#        'patinetes_elétricos': nan,
#        'região': 'Sudeste',
#        'sistema': 'Bike VV',
#        'tipologia_do_veículo': 'Bicicleta',
#        'usuários': nan,
#        'viagens_diárias': 2059.0}],
#      'viagens_diárias': 2059.0},
#     {'15_até_29_anos': 'Dados não disponíveis',
#      '30_até_59_anos': 'Dados não disponíveis',
#      'acima_de_60': 'Dados não disponíveis',
#      'bicicletas': 'Dados não disponíveis',
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Vila Velha',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 'Dados não disponíveis',
#      'homens': 'Dados não disponíveis',
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 'Dados não disponíveis',
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'sistema': 'Yellow',
#      'usuários': 'Dados não disponíveis',
#      'veiculos': [{'15_até_29_anos': nan,
#        '30_até_59_anos': nan,
#        'acima_de_60': nan,
#        'bicicletas': nan,
#        'bicicletas_elétricas': nan,
#        'cidade': 'Vila Velha',
#        'emissões_de_co2_evitadas': nan,
#        'estado': 'Espírito Santo',
#        'estações': nan,
#        'fonte_e_escopo_temporal': nan,
#        'homens': nan,
#        'lat': Series([], Name: latitude, dtype: float64),
#        'long': Series([], Name: longitude, dtype: float64),
#        'mulheres': nan,
#        'média_distância_percorrida_por_dia': nan,
#        'operadora': 'Yellow',
#        'patinetes_elétricos': nan,
#        'região': 'Sudeste',
#        'sistema': 'Yellow',
#        'tipologia_do_veículo': 'Patinete Eletrico',
#        'usuários': nan,
#        'viagens_diárias': nan}],
#      'viagens_diárias': 'Dados não disponíveis'}],
#    'usuários': 'Dados não disponíveis',
#    'viagens_diárias': 2059.0},
#   {'15_até_29_anos': 'Dados não disponíveis',
#    '30_até_59_anos': 'Dados não disponíveis',
#    'acima_de_60': 'Dados não disponíveis',
#    'bicicletas': 330.0,
#    'bicicletas_elétricas': 'Dados não disponíveis',
#    'cidade': 'Vitória',
#    'emissões_de_co2_evitadas': 'Dados não disponíveis',
#    'estado': 48    Espírito Santo
#    49    Espírito Santo
#    Name: estado, dtype: object,
#    'estações': 33.0,
#    'homens': 'Dados não disponíveis',
#    'lat': Series([], Name: latitude, dtype: float64),
#    'long': Series([], Name: longitude, dtype: float64),
#    'modais': [{'15_até_29_anos': 44.06,
#      '30_até_59_anos': 53.76,
#      'acima_de_60': 2.18,
#      'bicicletas': 330.0,
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Vitória',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 33.0,
#      'homens': 49.34,
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 50.66,
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'tipologia_do_veículo': 'Bicicleta',
#      'usuários': 15752.0,
#      'viagens_diárias': 655.0},
#     {'15_até_29_anos': 'Dados não disponíveis',
#      '30_até_59_anos': 'Dados não disponíveis',
#      'acima_de_60': 'Dados não disponíveis',
#      'bicicletas': 'Dados não disponíveis',
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Vitória',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 'Dados não disponíveis',
#      'homens': 'Dados não disponíveis',
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 'Dados não disponíveis',
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'tipologia_do_veículo': 'Patinete Eletrico',
#      'usuários': 'Dados não disponíveis',
#      'viagens_diárias': 'Dados não disponíveis'}],
#    'mulheres': 'Dados não disponíveis',
#    'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#    'patinetes_elétricos': 'Dados não disponíveis',
#    'sistemas': [{'15_até_29_anos': 44.06,
#      '30_até_59_anos': 53.76,
#      'acima_de_60': 2.18,
#      'bicicletas': 330.0,
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Vitória',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 33.0,
#      'homens': 49.34,
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 50.66,
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'sistema': 'Bike Vitória',
#      'usuários': 15752.0,
#      'veiculos': [{'15_até_29_anos': 44.06,
#        '30_até_59_anos': 53.76,
#        'acima_de_60': 2.18,
#        'bicicletas': 330.0,
#        'bicicletas_elétricas': nan,
#        'cidade': 'Vitória',
#        'emissões_de_co2_evitadas': nan,
#        'estado': 'Espírito Santo',
#        'estações': 33.0,
#        'fonte_e_escopo_temporal': 'Emissões de CO² evitadas: Calculado com base na distância percorrida por dia. Metodologia do cálculo desenvolvida em colaboração com o Instituto de Energia e Meio Ambiente (IEMA). \nNº de estações, nº de veículos, viagens diárias,  nº de usuários, sexo e idade: Calculados com base nos dados fornecidos em dezembro de 2019 pela operadora Serttel sobre o sistema, referentes aos meses de abril de 2019 a setembro de 2019. Maiores informações sobre o escopo e metodologia do cálculo dos dados encontram-se no relatório sobre a plataforma.',
#        'homens': 49.34,
#        'lat': Series([], Name: latitude, dtype: float64),
#        'long': Series([], Name: longitude, dtype: float64),
#        'mulheres': 50.66,
#        'média_distância_percorrida_por_dia': nan,
#        'operadora': 'Serttel',
#        'patinetes_elétricos': nan,
#        'região': 'Sudeste',
#        'sistema': 'Bike Vitória',
#        'tipologia_do_veículo': 'Bicicleta',
#        'usuários': 15752.0,
#        'viagens_diárias': 655.0}],
#      'viagens_diárias': 655.0},
#     {'15_até_29_anos': 'Dados não disponíveis',
#      '30_até_59_anos': 'Dados não disponíveis',
#      'acima_de_60': 'Dados não disponíveis',
#      'bicicletas': 'Dados não disponíveis',
#      'bicicletas_elétricas': 'Dados não disponíveis',
#      'cidade': 'Vitória',
#      'emissões_de_co2_evitadas': 'Dados não disponíveis',
#      'estações': 'Dados não disponíveis',
#      'homens': 'Dados não disponíveis',
#      'lat': Series([], Name: latitude, dtype: float64),
#      'long': Series([], Name: longitude, dtype: float64),
#      'mulheres': 'Dados não disponíveis',
#      'média_distância_percorrida_por_dia': 'Dados não disponíveis',
#      'patinetes_elétricos': 'Dados não disponíveis',
#      'sistema': 'Yellow',
#      'usuários': 'Dados não disponíveis',
#      'veiculos': [{'15_até_29_anos': nan,
#        '30_até_59_anos': nan,
#        'acima_de_60': nan,
#        'bicicletas': nan,
#        'bicicletas_elétricas': nan,
#        'cidade': 'Vitória',
#        'emissões_de_co2_evitadas': nan,
#        'estado': 'Espírito Santo',
#        'estações': nan,
#        'fonte_e_escopo_temporal': nan,
#        'homens': nan,
#        'lat': Series([], Name: latitude, dtype: float64),
#        'long': Series([], Name: longitude, dtype: float64),
#        'mulheres': nan,
#        'média_distância_percorrida_por_dia': nan,
#        'operadora': 'Yellow',
#        'patinetes_elétricos': nan,
#        'região': 'Sudeste',
#        'sistema': 'Yellow',
#        'tipologia_do_veículo': 'Patinete Eletrico',
#        'usuários': nan,
#        'viagens_diárias': nan}],
#      'viagens_diárias': 'Dados não disponíveis'}],
#    'usuários': 15752.0,
#    'viagens_diárias': 655.0}],
#  'média_distância_percorrida_por_dia': 173399.31,
#  'operadora': ['Tembici',
#   'Serttel',
#   'Yellow',
#   'Grin',
#   'Lime',
#   'Prefeitura de Salvador',
#   'Mobilicidade',
#   'Agencia Trunfo'],
#  'patinetes_elétricos': 'Dados não disponíveis',
#  'sistema_por_estado': [{'estado': 'Pará', 'sistemas': ['Bike Belém – PA']},
#   {'estado': 'Minas Gerais',
#    'sistemas': ['Bike BH – MG', 'Yellow – MG', 'Unimed Bike JF – MG']},
#   {'estado': 'São Paulo',
#    'sistemas': ['Rivibike – SP',
#     'Yellow – SP',
#     'Bike Santos – SP',
#     'Bike Kids Santos – SP',
#     'Bike Sanja – SP',
#     'Mobilicidade – SP',
#     'Grin – SP',
#     'Lime – SP',
#     'CicloSampa – SP',
#     'Bike Sampa – SP',
#     'Integrabike – SP']},
#   {'estado': 'Distrito Federal',
#    'sistemas': ['Mais Bike – DF', 'Yellow – DF']},
#   {'estado': 'Paraná', 'sistemas': ['Yellow – PR']},
#   {'estado': 'Santa Catarina', 'sistemas': ['Yellow – SC']},
#   {'estado': 'Ceará',
#    'sistemas': ['Bicicleta Integrada – CE', 'Bicicletar – CE']},
#   {'estado': 'Goiás', 'sistemas': ['GynDebike – GO']},
#   {'estado': 'Amazonas', 'sistemas': ['Manôbike – AM']},
#   {'estado': 'Rio de Janeiro',
#    'sistemas': ['Maricá – RJ',
#     'Grin – RJ',
#     'Lime – RJ',
#     'Bike Rio – RJ',
#     'Yellow – RJ']},
#   {'estado': 'Rio Grande do Sul',
#    'sistemas': ['Bike Pel – RS', 'Bike PoA – RS', 'Yellow – RS']},
#   {'estado': 'Pernambuco', 'sistemas': ['Petrobike – PE', 'Bike PE – PE']},
#   {'estado': 'Bahia',
#    'sistemas': ['Salvador Vai de Bike – BA', 'Bike Salvador – BA']},
#   {'estado': 'Espírito Santo',
#    'sistemas': ['Bike Serra – ES',
#     'Bike VV – ES',
#     'Yellow – ES',
#     'Bike Vitória – ES']}],
#  'sistema_total': ['Bike Belém – PA',
#   'Bike BH – MG',
#   'Yellow – MG',
#   'Unimed Bike JF – MG',
#   'Rivibike – SP',
#   'Yellow – SP',
#   'Bike Santos – SP',
#   'Bike Kids Santos – SP',
#   'Bike Sanja – SP',
#   'Mobilicidade – SP',
#   'Grin – SP',
#   'Lime – SP',
#   'CicloSampa – SP',
#   'Bike Sampa – SP',
#   'Integrabike – SP',
#   'Mais Bike – DF',
#   'Yellow – DF',
#   'Yellow – PR',
#   'Yellow – SC',
#   'Bicicleta Integrada – CE',
#   'Bicicletar – CE',
#   'GynDebike – GO',
#   'Manôbike – AM',
#   'Maricá – RJ',
#   'Grin – RJ',
#   'Lime – RJ',
#   'Bike Rio – RJ',
#   'Yellow – RJ',
#   'Bike Pel – RS',
#   'Bike PoA – RS',
#   'Yellow – RS',
#   'Petrobike – PE',
#   'Bike PE – PE',
#   'Salvador Vai de Bike – BA',
#   'Bike Salvador – BA',
#   'Bike Serra – ES',
#   'Bike VV – ES',
#   'Yellow – ES',
#   'Bike Vitória – ES'],
#  'usuários': 154791.0,
#  'viagens_diárias': 36785.0}

# %%
with open('final_file_labmob_v8.json', 'w') as json_file:
  json.dump(dicionario_final, json_file, encoding='utf-16',ignore_nan=True,ensure_ascii =False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-f67a2d5b6380> in <module>()
#       1 with open('final_file_labmob_v8.json', 'w') as json_file:
# ----> 2   json.dump(dicionario_final, json_file, encoding='utf-16',ignore_nan=True,ensure_ascii =False)
#
# /anaconda3/lib/python3.6/site-packages/simplejson/__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, encoding, default, use_decimal, namedtuple_as_object, tuple_as_array, bigint_as_string, sort_keys, item_sort_key, for_json, ignore_nan, int_as_string_bitcount, iterable_as_array, **kw)
#     276     # could accelerate with writelines in some versions of Python, at
#     277     # a debuggability cost
# --> 278     for chunk in iterable:
#     279         fp.write(chunk)
#     280
#
# /anaconda3/lib/python3.6/site-packages/simplejson/encoder.py in _iterencode(o, _current_indent_level)
#     694                         yield chunk
#     695                 elif isinstance(o, dict):
# --> 696                     for chunk in _iterencode_dict(o, _current_indent_level):
#     697                         yield chunk
#     698                 elif _use_decimal and isinstance(o, Decimal):
#
# /anaconda3/lib/python3.6/site-packages/simplejson/encoder.py in _iterencode_dict(dct, _current_indent_level)
#     650                     else:
#     651                         chunks = _iterencode(value, _current_indent_level)
# --> 652                 for chunk in chunks:
#     653                     yield chunk
#     654         if newline_indent is not None:
#
# /anaconda3/lib/python3.6/site-packages/simplejson/encoder.py in _iterencode_list(lst, _current_indent_level)
#     529                     else:
#     530                         chunks = _iterencode(value, _current_indent_level)
# --> 531                 for chunk in chunks:
#     532                     yield chunk
#     533         if first:
#
# /anaconda3/lib/python3.6/site-packages/simplejson/encoder.py in _iterencode_dict(dct, _current_indent_level)
#     650                     else:
#     651                         chunks = _iterencode(value, _current_indent_level)
# --> 652                 for chunk in chunks:
#     653                     yield chunk
#     654         if newline_indent is not None:
#
# /anaconda3/lib/python3.6/site-packages/simplejson/encoder.py in _iterencode(o, _current_indent_level)
#     714                             raise ValueError("Circular reference detected")
#     715                         markers[markerid] = o
# --> 716                     o = _default(o)
#     717                     for chunk in _iterencode(o, _current_indent_level):
#     718                         yield chunk
#
# /anaconda3/lib/python3.6/site-packages/simplejson/encoder.py in default(self, o)
#     271         """
#     272         raise TypeError('Object of type %s is not JSON serializable' %
# --> 273                         o.__class__.__name__)
#     274
#     275     def encode(self, o):
#
# TypeError: Object of type Series is not JSON serializable
